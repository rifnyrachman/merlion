# %% [markdown]
# ### This is a trial to run the meta-learning agent in the trial environment
# Population weights: Uniform

# %%
import os, sys
os.environ["PYTHONPATH"] = "/home/rifnyrachman7"
sys.path.append("/home/rifnyrachman7/_merlion/")
sys.path.append("/home/rifnyrachman7/_merlion/ds-project-messiah/src")
sys.path.append("/home/rifnyrachman7/")

# %%
from gymnasium.wrappers import TimeLimit
import gymnasium as gym
from pathlib import Path

# Import both modules
from _metamorl.algo_ray.rllib.algorithms.maml.merlion_main_multitasks import MERLION, MERLIONConfig
from _metamorl.algo_ray.rllib.algorithms.maml.callback_save_population import _find_archive , MERLIONWithSaveCallbacks

 #v2.3.1 #use algo from local repo
import ray
from ray import air, tune
from ray.tune.registry import register_env
from gymnasium.wrappers import TimeLimit
from ray.air import Checkpoint
from ray.rllib.algorithms.algorithm import Algorithm

# Import the required modules

from messiah.environment import Environment
from messiah.agents.processing import MaxAvailableProcessingAgent

import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

import tempfile
import pickle
import json


#from utils.plot_utils import PlotUtils

# %%
#import generated environment
from _merlion.random_env import complex_env_merlion
#complex_sc = complex_env_merlion.ComplexSC()
#simple_sc.save_filename = "/home/rifnyrachman7/_merlion/random_env/simple_reward.pkl"

# %%
def make_env(env_config=None):
    base = ComplexSC()
    base = ScalarizationWeightProxy(base)
    base = TimeLimit(base, max_episode_steps=100)   # outermost!
    return base

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def save_full_checkpoints_for_population(algo, out_dir: str):
    archive = _find_archive(algo)
    if archive is None:
        print("[SavePopulation] MERLION archive not found on algorithm; skipping.")
        return

    out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)

    pol = algo.get_policy()
    P = int(getattr(archive, "population_size", len(getattr(archive, "archive", []))))

    for i in range(P):
        item = archive.get_archive_item(i)
        if item is None:
            continue

        theta_i = item["theta"]
        w_i = np.asarray(item["weight"], dtype=np.float32)   # <- correct key

        # save the full RLlib checkpoint for policy i
        pol.set_weights(theta_i)
        ckpt_dir = out / f"checkpoint_policy_{i}"
        ckpt_dir.mkdir(parents=True, exist_ok=True)
        path = algo.save(str(ckpt_dir))
        print(f"[SavePopulation] Saved RLlib checkpoint for i={i} → {path}")

        # save the associated weight next to it
        with open(ckpt_dir / "weight.json", "w") as f:
            json.dump([float(x) for x in w_i.ravel().tolist()], f)

# %%
ray.shutdown()
ray.init()

register_env("complex_sc", lambda cfg: complex_env_merlion.make_env(cfg))

rollout_fragment_length = 32 #default 32
# Out:
# 2026-02-21 22:36:46,204	WARNING utils.py:640 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2026-02-21 22:36:46,206	WARNING utils.py:652 -- Ray currently does not support initializing Raywith fractional cpus. Your num_cpus will be truncated from 13.68 to 13.
# 2026-02-21 22:36:46,207	WARNING services.py:1780 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2026-02-21 22:36:46,244	INFO worker.py:1544 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265

# %% [markdown]
# ### Adaptation and Metalearning Phase

# %%
seed_base = 99

config = (
    MERLIONConfig()
    .rollouts(
        num_rollout_workers=4, rollout_fragment_length=rollout_fragment_length
    )
    .framework("torch")
    .environment("complex_sc", clip_actions=True)
    .training(
        inner_adaptation_steps=8,
        meta_batch_size=4, # follow rollout_workers in MIRACL that represent task batch number
        maml_optimizer_steps=10,
        gamma=0.99,
        lambda_=1.0,
        lr=0.001,
        vf_loss_coeff=0.5,
        inner_lr=0.03,
        use_meta_env=True,
        clip_param=0.3,
        kl_target=0.01,
        kl_coeff=0.001,
        model=dict(fcnet_hiddens=[64, 64]),
        train_batch_size=rollout_fragment_length,
        
        #MERLION specific parameters
        population_size = 21, #default # TO DO: ablation for this
        num_objectives = 3,
    )
    .evaluation(
        evaluation_num_workers=1,
        evaluation_interval=100,
        enable_async_evaluation=True,
    )
    .callbacks(MERLIONWithSaveCallbacks)
)

# %%
local_dir = "/home/rifnyrachman7/_merlion/training_data/complex_sc_v0"
num_iterations = 13 #default 500

results = {}
runs = [6] #run multiple times for model robustness
for k in runs:
    print(f"RUNNING NUMBER-{k}")
    
    tuner = tune.Tuner(
        MERLION,
        param_space=config.to_dict(),
        run_config=air.RunConfig(
            name=f"merlion_complex_{k}",
            local_dir = local_dir,
            stop={"training_iteration": num_iterations},
            failure_config=air.FailureConfig(fail_fast="raise"),
            log_to_file=True,
            checkpoint_config=air.CheckpointConfig(checkpoint_at_end=True, num_to_keep=1),  # ensure a checkpoint exists
        )
    )
    results[k] = tuner.fit()
    
    # #save the best checkpoint for each run
    best = results[k].get_best_result()
    algo = Algorithm.from_checkpoint(best.checkpoint)
    
    out_dir = os.path.join(local_dir, f"metapolicies-{k}")
    os.makedirs(out_dir, exist_ok=True)
    save_full_checkpoints_for_population(algo, out_dir)
# Out:
# RUNNING NUMBER-6
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-02-19 05:43:47</td></tr>
# <tr><td>Running for: </td><td>01:25:41.70        </td></tr>
# <tr><td>Memory:      </td><td>9.9/123.8 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 0/13 CPUs, 0/0 GPUs, 0.0/79.62 GiB heap, 0.0/9.31 GiB objects
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                    </th><th>status    </th><th>loc              </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">     ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>MERLION_complex_sc_fd7cf_00000</td><td>TERMINATED</td><td>10.131.58.11:1915</td><td style="text-align: right;">    13</td><td style="text-align: right;">         5124.96</td><td style="text-align: right;">1056900</td><td style="text-align: right;"> 31.2326</td><td style="text-align: right;">             45.1816</td><td style="text-align: right;">             15.8438</td><td style="text-align: right;">               100</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# /home/rifnyrachman7/.local/lib/python3.10/site-packages/ray/tune/execution/trial_runner.py:402: UserWarning: fail_fast='raise' detected. Be careful when using this mode as resources (such as Ray processes, file descriptors, and temporary files) may not be cleaned up properly. To use a safer mode, use fail_fast=True.
#   warnings.warn(
# (MERLION pid=1915) 2026-02-19 04:18:09,326	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# (MERLION pid=1915) 2026-02-19 04:18:09,326	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# (MERLION pid=1915) 2026-02-19 04:18:09,828	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (MERLION pid=1915) 2026-02-19 04:18:09,828	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=2001) 2026-02-19 04:18:13,500	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=2001) 2026-02-19 04:18:13,500	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=2001) 2026-02-19 04:18:13,500	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=2001) 2026-02-19 04:18:13,500	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (MERLION pid=1915) 2026-02-19 04:18:14,727	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (MERLION pid=1915) 2026-02-19 04:18:14,727	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (MERLION pid=1915) 2026-02-19 04:18:14,728	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (MERLION pid=1915) 2026-02-19 04:18:14,728	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (MERLION pid=1915) 2026-02-19 04:18:18,491	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# (MERLION pid=1915) 2026-02-19 04:18:18,491	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# (RolloutWorker pid=2357) 2026-02-19 04:18:21,960	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=2357) 2026-02-19 04:18:21,960	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=2357) 2026-02-19 04:18:21,960	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=2357) 2026-02-19 04:18:21,960	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (MERLION pid=1915) 2026-02-19 04:18:22,698	INFO trainable.py:172 -- Trainable.setup took 12.871 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (MERLION pid=1915) 2026-02-19 04:18:22,699	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 0) ===
# (MERLION pid=1915) 00 w=[0.205,0.707,0.088] obj=[   0.24,   0.77,   0.41] sc=    0.631  <- OK
# (MERLION pid=1915) 01 w=[0.163,0.086,0.751] obj=[   0.16,   0.79,   0.47] sc=    0.447  <- OK
# (MERLION pid=1915) 02 w=[0.022,0.746,0.232] obj=[   0.19,   0.75,   0.13] sc=    0.593  <- OK
# (MERLION pid=1915) 03 w=[0.453,0.092,0.456] obj=[   0.22,   0.78,   0.24] sc=    0.276  <- OK
# (MERLION pid=1915) 04 w=[0.405,0.012,0.582] obj=[   0.19,   0.76,   0.22] sc=    0.215  <- OK
# (MERLION pid=1915) 05 w=[0.683,0.243,0.074] obj=[   0.20,   0.77,   0.16] sc=    0.333  <- OK
# (MERLION pid=1915) 06 w=[0.390,0.302,0.308] obj=[   0.19,   0.77,   0.26] sc=    0.388  <- OK
# (MERLION pid=1915) 07 w=[0.049,0.105,0.846] obj=[   0.19,   0.76,   0.14] sc=    0.205  <- OK
# (MERLION pid=1915) 08 w=[0.384,0.474,0.142] obj=[   0.20,   0.76,   0.37] sc=    0.489  <- OK
# (MERLION pid=1915) 09 w=[0.262,0.519,0.219] obj=[   0.20,   0.75,   0.17] sc=    0.482  <- OK
# (MERLION pid=1915) 10 w=[0.028,0.960,0.012] obj=[   0.16,   0.76,   0.16] sc=    0.735  <- OK
# (MERLION pid=1915) 11 w=[0.549,0.014,0.437] obj=[   0.18,   0.76,   0.30] sc=    0.243  <- OK
# (MERLION pid=1915) 12 w=[0.451,0.432,0.117] obj=[   0.23,   0.76,   0.18] sc=    0.451  <- OK
# (MERLION pid=1915) 13 w=[0.348,0.275,0.377] obj=[   0.20,   0.77,   0.21] sc=    0.361  <- OK
# (MERLION pid=1915) 14 w=[0.563,0.029,0.408] obj=[   0.19,   0.77,   0.23] sc=    0.225  <- OK
# (MERLION pid=1915) 15 w=[0.435,0.432,0.133] obj=[   0.20,   0.77,   0.20] sc=    0.444  <- OK
# (MERLION pid=1915) 16 w=[0.106,0.436,0.459] obj=[   0.20,   0.76,   0.14] sc=    0.420  <- OK
# (MERLION pid=1915) 17 w=[0.171,0.277,0.552] obj=[   0.19,   0.76,   0.21] sc=    0.363  <- OK
# (MERLION pid=1915) 18 w=[0.017,0.567,0.416] obj=[   0.21,   0.76,   0.09] sc=    0.470  <- OK
# (MERLION pid=1915) 19 w=[0.153,0.500,0.347] obj=[   0.17,   0.76,   0.10] sc=    0.440  <- OK
# (MERLION pid=1915) 20 w=[0.726,0.193,0.081] obj=[   0.19,   0.77,   0.41] sc=    0.324  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=81300
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                    </th><th style="text-align: right;">  adaptation_delta</th><th style="text-align: right;">  agent_timesteps_total</th><th>connector_metrics                                                                                                                                              </th><th>custom_metrics  </th><th>date               </th><th>done  </th><th style="text-align: right;">  episode_len_mean</th><th>episode_media  </th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_max_adapt_1</th><th style="text-align: right;">  episode_reward_max_adapt_2</th><th style="text-align: right;">  episode_reward_max_adapt_3</th><th style="text-align: right;">  episode_reward_max_adapt_4</th><th style="text-align: right;">  episode_reward_max_adapt_5</th><th style="text-align: right;">  episode_reward_max_adapt_6</th><th style="text-align: right;">  episode_reward_max_adapt_7</th><th style="text-align: right;">  episode_reward_max_adapt_8</th><th style="text-align: right;">  episode_reward_mean</th><th style="text-align: right;">  episode_reward_mean_adapt_1</th><th style="text-align: right;">  episode_reward_mean_adapt_2</th><th style="text-align: right;">  episode_reward_mean_adapt_3</th><th style="text-align: right;">  episode_reward_mean_adapt_4</th><th style="text-align: right;">  episode_reward_mean_adapt_5</th><th style="text-align: right;">  episode_reward_mean_adapt_6</th><th style="text-align: right;">  episode_reward_mean_adapt_7</th><th style="text-align: right;">  episode_reward_mean_adapt_8</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_reward_min_adapt_1</th><th style="text-align: right;">  episode_reward_min_adapt_2</th><th style="text-align: right;">  episode_reward_min_adapt_3</th><th style="text-align: right;">  episode_reward_min_adapt_4</th><th style="text-align: right;">  episode_reward_min_adapt_5</th><th style="text-align: right;">  episode_reward_min_adapt_6</th><th style="text-align: right;">  episode_reward_min_adapt_7</th><th style="text-align: right;">  episode_reward_min_adapt_8</th><th style="text-align: right;">  episodes_this_iter</th><th style="text-align: right;">  episodes_total</th><th>experiment_id                   </th><th>hostname                                        </th><th>info                                                                                                                                                                                                                                                                                                                                                                                     </th><th style="text-align: right;">  iterations_since_restore</th><th>node_ip     </th><th style="text-align: right;">  num_faulty_episodes</th><th style="text-align: right;">  num_healthy_workers</th><th>perf                                                                          </th><th style="text-align: right;">  pid</th><th>policy_reward_max  </th><th>policy_reward_mean  </th><th>policy_reward_min  </th><th>sampler_perf                                                                                                                                                                                                   </th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th>timers  </th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th style="text-align: right;">  timesteps_this_iter</th><th style="text-align: right;">  timesteps_total</th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>MERLION_complex_sc_fd7cf_00000</td><td style="text-align: right;">           2.84073</td><td style="text-align: right;">                      0</td><td>{&#x27;ObsPreprocessorConnector_ms&#x27;: 0.004440998632168371, &#x27;StateBufferConnector_ms&#x27;: 0.003204106364010844, &#x27;ViewRequirementAgentConnector_ms&#x27;: 0.07759545914147965}</td><td>{}              </td><td>2026-02-19_05-43-47</td><td>True  </td><td style="text-align: right;">               100</td><td>{}             </td><td style="text-align: right;">             45.1816</td><td style="text-align: right;">                     41.6111</td><td style="text-align: right;">                      39.501</td><td style="text-align: right;">                     45.3355</td><td style="text-align: right;">                     40.5196</td><td style="text-align: right;">                     39.0907</td><td style="text-align: right;">                     42.2278</td><td style="text-align: right;">                     39.4058</td><td style="text-align: right;">                     38.4537</td><td style="text-align: right;">              31.2326</td><td style="text-align: right;">                      30.6099</td><td style="text-align: right;">                      30.3007</td><td style="text-align: right;">                      33.1519</td><td style="text-align: right;">                      32.7499</td><td style="text-align: right;">                      33.5532</td><td style="text-align: right;">                      36.2871</td><td style="text-align: right;">                      31.1483</td><td style="text-align: right;">                      34.0733</td><td style="text-align: right;">             15.8438</td><td style="text-align: right;">                     19.0557</td><td style="text-align: right;">                     14.3197</td><td style="text-align: right;">                     21.2469</td><td style="text-align: right;">                     21.8942</td><td style="text-align: right;">                     28.1941</td><td style="text-align: right;">                     24.2573</td><td style="text-align: right;">                     23.3278</td><td style="text-align: right;">                     29.7369</td><td style="text-align: right;">                 777</td><td style="text-align: right;">           10101</td><td>6d1b934de7fe42c38e02f8c2dee32196</td><td>workspace-580f8f1b-0605-48d2-b4f5-8608dc1d24e9-0</td><td>{&#x27;learner&#x27;: {&#x27;default_policy&#x27;: {&#x27;learner_stats&#x27;: {&#x27;allreduce_latency&#x27;: 0.0, &#x27;grad_gnorm&#x27;: 1.0, &#x27;worker_loss&#x27;: 18.21945571899414}, &#x27;model&#x27;: {}, &#x27;custom_metrics&#x27;: {}, &#x27;num_agent_steps_trained&#x27;: 3600, &#x27;num_grad_updates_lifetime&#x27;: 754, &#x27;diff_num_grad_updates_vs_sampler_policy&#x27;: 9.0}}, &#x27;num_steps_sampled&#x27;: 975600, &#x27;num_steps_trained_this_iter&#x27;: 81300, &#x27;num_steps_trained&#x27;: 975600}</td><td style="text-align: right;">                        13</td><td>10.131.58.11</td><td style="text-align: right;">                    0</td><td style="text-align: right;">                    5</td><td>{&#x27;cpu_util_percent&#x27;: 8.087387387387388, &#x27;ram_util_percent&#x27;: 7.895855855855854}</td><td style="text-align: right;"> 1915</td><td>{}                 </td><td>{}                  </td><td>{}                 </td><td>{&#x27;mean_raw_obs_processing_ms&#x27;: 1.0718007622384746, &#x27;mean_inference_ms&#x27;: 0.6954476225643293, &#x27;mean_action_processing_ms&#x27;: 0.1316390780130963, &#x27;mean_env_wait_ms&#x27;: 2.7645482495950215, &#x27;mean_env_render_ms&#x27;: 0.0}</td><td style="text-align: right;">             5124.96</td><td style="text-align: right;">           390.299</td><td style="text-align: right;">       5124.96</td><td>{}      </td><td style="text-align: right;"> 1771479827</td><td style="text-align: right;">                  1056900</td><td style="text-align: right;">                81300</td><
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 1) ===
# (MERLION pid=1915) 00 w=[0.028,0.960,0.012] obj=[   0.22,   0.75,   0.15] sc=    0.732  <- OK
# (MERLION pid=1915) 01 w=[0.261,0.681,0.058] obj=[   0.19,   0.76,   0.36] sc=    0.588  <- OK
# (MERLION pid=1915) 02 w=[0.173,0.583,0.244] obj=[   0.21,   0.76,   0.16] sc=    0.517  <- OK
# (MERLION pid=1915) 03 w=[0.436,0.306,0.257] obj=[   0.19,   0.77,   0.33] sc=    0.404  <- OK
# (MERLION pid=1915) 04 w=[0.210,0.643,0.146] obj=[   0.20,   0.77,   0.37] sc=    0.591  <- OK
# (MERLION pid=1915) 05 w=[0.003,0.131,0.866] obj=[   0.22,   0.77,   0.12] sc=    0.207  <- OK
# (MERLION pid=1915) 06 w=[0.723,0.133,0.144] obj=[   0.16,   0.77,   0.26] sc=    0.258  <- OK
# (MERLION pid=1915) 07 w=[0.045,0.258,0.696] obj=[   0.20,   0.76,   0.19] sc=    0.335  <- OK
# (MERLION pid=1915) 08 w=[0.619,0.237,0.145] obj=[   0.18,   0.77,   0.23] sc=    0.328  <- OK
# (MERLION pid=1915) 09 w=[0.395,0.227,0.377] obj=[   0.22,   0.76,   0.33] sc=    0.381  <- OK
# (MERLION pid=1915) 10 w=[0.359,0.390,0.251] obj=[   0.21,   0.76,   0.15] sc=    0.406  <- OK
# (MERLION pid=1915) 11 w=[0.492,0.284,0.223] obj=[   0.18,   0.76,   0.17] sc=    0.343  <- OK
# (MERLION pid=1915) 12 w=[0.113,0.500,0.387] obj=[   0.22,   0.76,   0.13] sc=    0.457  <- OK
# (MERLION pid=1915) 13 w=[0.041,0.440,0.520] obj=[   0.22,   0.75,   0.17] sc=    0.428  <- OK
# (MERLION pid=1915) 14 w=[0.161,0.553,0.286] obj=[   0.18,   0.77,   0.33] sc=    0.548  <- OK
# (MERLION pid=1915) 15 w=[0.126,0.713,0.160] obj=[   0.22,   0.76,   0.10] sc=    0.584  <- OK
# (MERLION pid=1915) 16 w=[0.103,0.314,0.583] obj=[   0.19,   0.77,   0.19] sc=    0.371  <- OK
# (MERLION pid=1915) 17 w=[0.155,0.700,0.144] obj=[   0.20,   0.77,   0.41] sc=    0.626  <- OK
# (MERLION pid=1915) 18 w=[0.661,0.273,0.066] obj=[   0.19,   0.77,   0.15] sc=    0.341  <- OK
# (MERLION pid=1915) 19 w=[0.290,0.427,0.283] obj=[   0.19,   0.77,   0.34] sc=    0.479  <- OK
# (MERLION pid=1915) 20 w=[0.000,0.655,0.345] obj=[   0.19,   0.76,   0.14] sc=    0.549  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=162600
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 2) ===
# (MERLION pid=1915) 00 w=[0.003,0.131,0.866] obj=[   0.20,   0.76,   0.20] sc=    0.273  <- OK
# (MERLION pid=1915) 01 w=[0.024,0.806,0.171] obj=[   0.17,   0.77,   0.23] sc=    0.661  <- OK
# (MERLION pid=1915) 02 w=[0.353,0.647,0.000] obj=[   0.19,   0.76,   0.38] sc=    0.559  <- OK
# (MERLION pid=1915) 03 w=[0.040,0.269,0.691] obj=[   0.21,   0.76,   0.12] sc=    0.297  <- OK
# (MERLION pid=1915) 04 w=[0.016,0.561,0.422] obj=[   0.18,   0.76,   0.15] sc=    0.494  <- OK
# (MERLION pid=1915) 05 w=[0.621,0.328,0.051] obj=[   0.20,   0.77,   0.17] sc=    0.385  <- OK
# (MERLION pid=1915) 06 w=[0.320,0.314,0.366] obj=[   0.18,   0.77,   0.31] sc=    0.414  <- OK
# (MERLION pid=1915) 07 w=[0.370,0.210,0.420] obj=[   0.20,   0.76,   0.12] sc=    0.287  <- OK
# (MERLION pid=1915) 08 w=[0.271,0.325,0.404] obj=[   0.24,   0.75,   0.32] sc=    0.442  <- OK
# (MERLION pid=1915) 09 w=[0.420,0.339,0.241] obj=[   0.23,   0.75,   0.20] sc=    0.397  <- OK
# (MERLION pid=1915) 10 w=[0.000,0.423,0.577] obj=[   0.18,   0.76,   0.11] sc=    0.388  <- OK
# (MERLION pid=1915) 11 w=[0.070,0.420,0.510] obj=[   0.21,   0.76,   0.14] sc=    0.406  <- OK
# (MERLION pid=1915) 12 w=[0.012,0.419,0.568] obj=[   0.22,   0.76,   0.13] sc=    0.395  <- OK
# (MERLION pid=1915) 13 w=[0.473,0.232,0.295] obj=[   0.24,   0.76,   0.10] sc=    0.319  <- OK
# (MERLION pid=1915) 14 w=[0.014,0.479,0.508] obj=[   0.20,   0.77,   0.36] sc=    0.553  <- OK
# (MERLION pid=1915) 15 w=[0.193,0.632,0.175] obj=[   0.21,   0.76,   0.21] sc=    0.558  <- OK
# (MERLION pid=1915) 16 w=[0.166,0.624,0.210] obj=[   0.20,   0.77,   0.25] sc=    0.565  <- OK
# (MERLION pid=1915) 17 w=[0.277,0.723,0.000] obj=[   0.15,   0.77,   0.10] sc=    0.595  <- OK
# (MERLION pid=1915) 18 w=[0.009,0.316,0.675] obj=[   0.20,   0.77,   0.18] sc=    0.365  <- OK
# (MERLION pid=1915) 19 w=[0.000,0.210,0.790] obj=[   0.17,   0.76,   0.15] sc=    0.282  <- OK
# (MERLION pid=1915) 20 w=[0.225,0.674,0.101] obj=[   0.15,   0.77,   0.29] sc=    0.584  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=243900
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 3) ===
# (MERLION pid=1915) 00 w=[0.621,0.328,0.051] obj=[   0.22,   0.76,   0.14] sc=    0.392  <- OK
# (MERLION pid=1915) 01 w=[0.170,0.376,0.454] obj=[   0.19,   0.76,   0.15] sc=    0.385  <- OK
# (MERLION pid=1915) 02 w=[0.113,0.186,0.701] obj=[   0.18,   0.76,   0.18] sc=    0.286  <- OK
# (MERLION pid=1915) 03 w=[0.207,0.686,0.108] obj=[   0.16,   0.76,   0.39] sc=    0.596  <- OK
# (MERLION pid=1915) 04 w=[0.245,0.488,0.267] obj=[   0.17,   0.76,   0.07] sc=    0.432  <- OK
# (MERLION pid=1915) 05 w=[0.303,0.287,0.411] obj=[   0.22,   0.77,   0.18] sc=    0.359  <- OK
# (MERLION pid=1915) 06 w=[0.013,0.436,0.551] obj=[   0.23,   0.76,   0.42] sc=    0.567  <- OK
# (MERLION pid=1915) 07 w=[0.124,0.391,0.485] obj=[   0.20,   0.77,   0.12] sc=    0.384  <- OK
# (MERLION pid=1915) 08 w=[0.000,0.552,0.448] obj=[   0.19,   0.77,   0.14] sc=    0.484  <- OK
# (MERLION pid=1915) 09 w=[0.502,0.374,0.124] obj=[   0.20,   0.75,   0.19] sc=    0.407  <- OK
# (MERLION pid=1915) 10 w=[0.114,0.293,0.593] obj=[   0.19,   0.75,   0.38] sc=    0.471  <- OK
# (MERLION pid=1915) 11 w=[0.015,0.516,0.469] obj=[   0.19,   0.77,   0.29] sc=    0.535  <- OK
# (MERLION pid=1915) 12 w=[0.047,0.050,0.902] obj=[   0.21,   0.75,   0.31] sc=    0.325  <- OK
# (MERLION pid=1915) 13 w=[0.000,0.163,0.837] obj=[   0.20,   0.76,   0.17] sc=    0.266  <- OK
# (MERLION pid=1915) 14 w=[0.377,0.358,0.265] obj=[   0.22,   0.75,   0.19] sc=    0.404  <- OK
# (MERLION pid=1915) 15 w=[0.491,0.162,0.348] obj=[   0.19,   0.76,   0.09] sc=    0.249  <- OK
# (MERLION pid=1915) 16 w=[0.067,0.268,0.665] obj=[   0.22,   0.76,   0.13] sc=    0.307  <- OK
# (MERLION pid=1915) 17 w=[0.488,0.285,0.227] obj=[   0.21,   0.76,   0.13] sc=    0.349  <- OK
# (MERLION pid=1915) 18 w=[0.124,0.157,0.720] obj=[   0.20,   0.76,   0.14] sc=    0.248  <- OK
# (MERLION pid=1915) 19 w=[0.576,0.381,0.043] obj=[   0.21,   0.77,   0.34] sc=    0.429  <- OK
# (MERLION pid=1915) 20 w=[0.338,0.238,0.424] obj=[   0.21,   0.77,   0.14] sc=    0.313  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=325200
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 4) ===
# (MERLION pid=1915) 00 w=[0.047,0.050,0.902] obj=[   0.21,   0.76,   0.29] sc=    0.307  <- OK
# (MERLION pid=1915) 01 w=[0.236,0.226,0.538] obj=[   0.20,   0.76,   0.31] sc=    0.384  <- OK
# (MERLION pid=1915) 02 w=[0.022,0.513,0.464] obj=[   0.23,   0.76,   0.17] sc=    0.474  <- OK
# (MERLION pid=1915) 03 w=[0.582,0.230,0.189] obj=[   0.21,   0.75,   0.10] sc=    0.312  <- OK
# (MERLION pid=1915) 04 w=[0.174,0.554,0.272] obj=[   0.18,   0.77,   0.31] sc=    0.540  <- OK
# (MERLION pid=1915) 05 w=[0.527,0.274,0.199] obj=[   0.21,   0.77,   0.21] sc=    0.364  <- OK
# (MERLION pid=1915) 06 w=[0.194,0.404,0.402] obj=[   0.17,   0.76,   0.12] sc=    0.389  <- OK
# (MERLION pid=1915) 07 w=[0.131,0.137,0.732] obj=[   0.21,   0.76,   0.35] sc=    0.385  <- OK
# (MERLION pid=1915) 08 w=[0.283,0.176,0.541] obj=[   0.23,   0.76,   0.19] sc=    0.302  <- OK
# (MERLION pid=1915) 09 w=[0.184,0.206,0.610] obj=[   0.19,   0.77,   0.13] sc=    0.275  <- OK
# (MERLION pid=1915) 10 w=[0.583,0.376,0.041] obj=[   0.19,   0.76,   0.16] sc=    0.404  <- OK
# (MERLION pid=1915) 11 w=[0.012,0.217,0.771] obj=[   0.14,   0.77,   0.11] sc=    0.252  <- OK
# (MERLION pid=1915) 12 w=[0.135,0.097,0.768] obj=[   0.23,   0.76,   0.17] sc=    0.235  <- OK
# (MERLION pid=1915) 13 w=[0.286,0.220,0.494] obj=[   0.21,   0.76,   0.09] sc=    0.273  <- OK
# (MERLION pid=1915) 14 w=[0.417,0.274,0.309] obj=[   0.17,   0.76,   0.14] sc=    0.323  <- OK
# (MERLION pid=1915) 15 w=[0.237,0.227,0.536] obj=[   0.19,   0.76,   0.19] sc=    0.323  <- OK
# (MERLION pid=1915) 16 w=[0.368,0.206,0.426] obj=[   0.22,   0.77,   0.12] sc=    0.286  <- OK
# (MERLION pid=1915) 17 w=[0.057,0.039,0.904] obj=[   0.19,   0.76,   0.12] sc=    0.147  <- OK
# (MERLION pid=1915) 18 w=[0.528,0.357,0.115] obj=[   0.20,   0.76,   0.11] sc=    0.389  <- OK
# (MERLION pid=1915) 19 w=[0.169,0.115,0.715] obj=[   0.21,   0.75,   0.40] sc=    0.406  <- OK
# (MERLION pid=1915) 20 w=[0.098,0.254,0.647] obj=[   0.19,   0.76,   0.21] sc=    0.347  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=406500
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 5) ===
# (MERLION pid=1915) 00 w=[0.583,0.376,0.041] obj=[   0.20,   0.76,   0.10] sc=    0.407  <- OK
# (MERLION pid=1915) 01 w=[0.003,0.102,0.895] obj=[   0.19,   0.76,   0.24] sc=    0.290  <- OK
# (MERLION pid=1915) 02 w=[0.153,0.115,0.732] obj=[   0.19,   0.76,   0.20] sc=    0.266  <- OK
# (MERLION pid=1915) 03 w=[0.262,0.206,0.532] obj=[   0.18,   0.76,   0.33] sc=    0.376  <- OK
# (MERLION pid=1915) 04 w=[0.000,0.577,0.423] obj=[   0.20,   0.76,   0.37] sc=    0.595  <- OK
# (MERLION pid=1915) 05 w=[0.352,0.236,0.412] obj=[   0.18,   0.77,   0.19] sc=    0.322  <- OK
# (MERLION pid=1915) 06 w=[0.538,0.354,0.108] obj=[   0.19,   0.75,   0.21] sc=    0.392  <- OK
# (MERLION pid=1915) 07 w=[0.244,0.176,0.581] obj=[   0.18,   0.78,   0.35] sc=    0.383  <- OK
# (MERLION pid=1915) 08 w=[0.244,0.197,0.559] obj=[   0.21,   0.76,   0.27] sc=    0.350  <- OK
# (MERLION pid=1915) 09 w=[0.254,0.176,0.570] obj=[   0.18,   0.77,   0.20] sc=    0.292  <- OK
# (MERLION pid=1915) 10 w=[0.086,0.074,0.841] obj=[   0.18,   0.78,   0.39] sc=    0.398  <- OK
# (MERLION pid=1915) 11 w=[0.000,0.000,1.000] obj=[   0.18,   0.76,   0.22] sc=    0.220  <- OK
# (MERLION pid=1915) 12 w=[0.101,0.084,0.815] obj=[   0.20,   0.75,   0.13] sc=    0.185  <- OK
# (MERLION pid=1915) 13 w=[0.400,0.261,0.338] obj=[   0.21,   0.77,   0.22] sc=    0.360  <- OK
# (MERLION pid=1915) 14 w=[0.091,0.071,0.838] obj=[   0.19,   0.76,   0.09] sc=    0.151  <- OK
# (MERLION pid=1915) 15 w=[0.191,0.079,0.730] obj=[   0.17,   0.76,   0.18] sc=    0.225  <- OK
# (MERLION pid=1915) 16 w=[0.284,0.148,0.567] obj=[   0.18,   0.77,   0.15] sc=    0.252  <- OK
# (MERLION pid=1915) 17 w=[0.023,0.000,0.977] obj=[   0.20,   0.77,   0.13] sc=    0.129  <- OK
# (MERLION pid=1915) 18 w=[0.385,0.208,0.407] obj=[   0.17,   0.77,   0.15] sc=    0.289  <- OK
# (MERLION pid=1915) 19 w=[0.117,0.246,0.638] obj=[   0.22,   0.76,   0.20] sc=    0.338  <- OK
# (MERLION pid=1915) 20 w=[0.112,0.173,0.715] obj=[   0.22,   0.76,   0.12] sc=    0.239  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=487800
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 6) ===
# (MERLION pid=1915) 00 w=[0.583,0.376,0.041] obj=[   0.20,   0.76,   0.16] sc=    0.410  <- OK
# (MERLION pid=1915) 01 w=[0.000,0.169,0.831] obj=[   0.20,   0.76,   0.35] sc=    0.424  <- OK
# (MERLION pid=1915) 02 w=[0.048,0.000,0.952] obj=[   0.20,   0.77,   0.21] sc=    0.205  <- OK
# (MERLION pid=1915) 03 w=[0.503,0.337,0.160] obj=[   0.20,   0.76,   0.18] sc=    0.386  <- OK
# (MERLION pid=1915) 04 w=[0.210,0.200,0.590] obj=[   0.22,   0.77,   0.14] sc=    0.279  <- OK
# (MERLION pid=1915) 05 w=[0.383,0.242,0.375] obj=[   0.17,   0.77,   0.22] sc=    0.335  <- OK
# (MERLION pid=1915) 06 w=[0.412,0.318,0.270] obj=[   0.20,   0.76,   0.12] sc=    0.359  <- OK
# (MERLION pid=1915) 07 w=[0.188,0.102,0.710] obj=[   0.18,   0.76,   0.13] sc=    0.204  <- OK
# (MERLION pid=1915) 08 w=[0.450,0.202,0.348] obj=[   0.18,   0.76,   0.14] sc=    0.282  <- OK
# (MERLION pid=1915) 09 w=[0.201,0.122,0.677] obj=[   0.21,   0.76,   0.34] sc=    0.368  <- OK
# (MERLION pid=1915) 10 w=[0.385,0.243,0.372] obj=[   0.20,   0.76,   0.12] sc=    0.308  <- OK
# (MERLION pid=1915) 11 w=[0.259,0.167,0.573] obj=[   0.20,   0.76,   0.36] sc=    0.383  <- OK
# (MERLION pid=1915) 12 w=[0.000,0.000,1.000] obj=[   0.16,   0.76,   0.14] sc=    0.136  <- OK
# (MERLION pid=1915) 13 w=[0.291,0.198,0.511] obj=[   0.18,   0.77,   0.08] sc=    0.247  <- OK
# (MERLION pid=1915) 14 w=[0.119,0.131,0.750] obj=[   0.23,   0.77,   0.16] sc=    0.248  <- OK
# (MERLION pid=1915) 15 w=[0.402,0.326,0.272] obj=[   0.17,   0.76,   0.16] sc=    0.358  <- OK
# (MERLION pid=1915) 16 w=[0.302,0.205,0.493] obj=[   0.21,   0.76,   0.36] sc=    0.396  <- OK
# (MERLION pid=1915) 17 w=[0.166,0.260,0.575] obj=[   0.21,   0.76,   0.21] sc=    0.351  <- OK
# (MERLION pid=1915) 18 w=[0.061,0.000,0.939] obj=[   0.21,   0.76,   0.13] sc=    0.139  <- OK
# (MERLION pid=1915) 19 w=[0.238,0.189,0.574] obj=[   0.18,   0.76,   0.18] sc=    0.292  <- OK
# (MERLION pid=1915) 20 w=[0.576,0.331,0.093] obj=[   0.19,   0.77,   0.15] sc=    0.378  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=569100
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 7) ===
# (MERLION pid=1915) 00 w=[0.583,0.376,0.041] obj=[   0.22,   0.76,   0.13] sc=    0.418  <- OK
# (MERLION pid=1915) 01 w=[0.143,0.108,0.749] obj=[   0.22,   0.76,   0.28] sc=    0.323  <- OK
# (MERLION pid=1915) 02 w=[0.106,0.072,0.823] obj=[   0.15,   0.78,   0.27] sc=    0.297  <- OK
# (MERLION pid=1915) 03 w=[0.269,0.170,0.560] obj=[   0.20,   0.76,   0.22] sc=    0.306  <- OK
# (MERLION pid=1915) 04 w=[0.536,0.371,0.093] obj=[   0.21,   0.77,   0.26] sc=    0.420  <- OK
# (MERLION pid=1915) 05 w=[0.272,0.169,0.558] obj=[   0.21,   0.76,   0.34] sc=    0.378  <- OK
# (MERLION pid=1915) 06 w=[0.475,0.224,0.301] obj=[   0.22,   0.77,   0.22] sc=    0.340  <- OK
# (MERLION pid=1915) 07 w=[0.364,0.335,0.301] obj=[   0.22,   0.76,   0.30] sc=    0.427  <- OK
# (MERLION pid=1915) 08 w=[0.340,0.219,0.441] obj=[   0.22,   0.77,   0.37] sc=    0.405  <- OK
# (MERLION pid=1915) 09 w=[0.060,0.157,0.783] obj=[   0.21,   0.76,   0.10] sc=    0.211  <- OK
# (MERLION pid=1915) 10 w=[0.382,0.242,0.375] obj=[   0.21,   0.77,   0.14] sc=    0.317  <- OK
# (MERLION pid=1915) 11 w=[0.411,0.328,0.261] obj=[   0.22,   0.75,   0.11] sc=    0.366  <- OK
# (MERLION pid=1915) 12 w=[0.109,0.208,0.684] obj=[   0.19,   0.75,   0.11] sc=    0.251  <- OK
# (MERLION pid=1915) 13 w=[0.000,0.000,1.000] obj=[   0.17,   0.76,   0.39] sc=    0.388  <- OK
# (MERLION pid=1915) 14 w=[0.313,0.180,0.507] obj=[   0.21,   0.76,   0.27] sc=    0.340  <- OK
# (MERLION pid=1915) 15 w=[0.399,0.229,0.372] obj=[   0.16,   0.77,   0.12] sc=    0.282  <- OK
# (MERLION pid=1915) 16 w=[0.062,0.039,0.899] obj=[   0.21,   0.77,   0.11] sc=    0.144  <- OK
# (MERLION pid=1915) 17 w=[0.078,0.052,0.870] obj=[   0.21,   0.75,   0.18] sc=    0.209  <- OK
# (MERLION pid=1915) 18 w=[0.000,0.088,0.912] obj=[   0.22,   0.77,   0.14] sc=    0.197  <- OK
# (MERLION pid=1915) 19 w=[0.462,0.321,0.217] obj=[   0.21,   0.76,   0.08] sc=    0.356  <- OK
# (MERLION pid=1915) 20 w=[0.089,0.000,0.911] obj=[   0.20,   0.76,   0.24] sc=    0.237  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=650400
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 8) ===
# (MERLION pid=1915) 00 w=[0.583,0.376,0.041] obj=[   0.16,   0.76,   0.35] sc=    0.393  <- OK
# (MERLION pid=1915) 01 w=[0.252,0.175,0.573] obj=[   0.21,   0.77,   0.18] sc=    0.287  <- OK
# (MERLION pid=1915) 02 w=[0.577,0.423,0.000] obj=[   0.21,   0.76,   0.14] sc=    0.445  <- OK
# (MERLION pid=1915) 03 w=[0.419,0.319,0.263] obj=[   0.22,   0.75,   0.28] sc=    0.404  <- OK
# (MERLION pid=1915) 04 w=[0.383,0.318,0.299] obj=[   0.18,   0.77,   0.20] sc=    0.374  <- OK
# (MERLION pid=1915) 05 w=[0.334,0.224,0.442] obj=[   0.22,   0.75,   0.09] sc=    0.282  <- OK
# (MERLION pid=1915) 06 w=[0.078,0.079,0.844] obj=[   0.22,   0.76,   0.34] sc=    0.361  <- OK
# (MERLION pid=1915) 07 w=[0.317,0.221,0.462] obj=[   0.21,   0.75,   0.12] sc=    0.289  <- OK
# (MERLION pid=1915) 08 w=[0.414,0.287,0.299] obj=[   0.20,   0.75,   0.12] sc=    0.336  <- OK
# (MERLION pid=1915) 09 w=[0.174,0.112,0.714] obj=[   0.18,   0.75,   0.22] sc=    0.270  <- OK
# (MERLION pid=1915) 10 w=[0.117,0.076,0.807] obj=[   0.17,   0.77,   0.13] sc=    0.182  <- OK
# (MERLION pid=1915) 11 w=[0.129,0.074,0.796] obj=[   0.21,   0.76,   0.24] sc=    0.273  <- OK
# (MERLION pid=1915) 12 w=[0.245,0.170,0.586] obj=[   0.17,   0.77,   0.17] sc=    0.274  <- OK
# (MERLION pid=1915) 13 w=[0.409,0.265,0.326] obj=[   0.19,   0.76,   0.32] sc=    0.383  <- OK
# (MERLION pid=1915) 14 w=[0.132,0.041,0.826] obj=[   0.23,   0.75,   0.13] sc=    0.168  <- OK
# (MERLION pid=1915) 15 w=[0.184,0.073,0.742] obj=[   0.19,   0.76,   0.30] sc=    0.314  <- OK
# (MERLION pid=1915) 16 w=[0.000,0.101,0.899] obj=[   0.19,   0.76,   0.18] sc=    0.236  <- OK
# (MERLION pid=1915) 17 w=[0.322,0.378,0.300] obj=[   0.21,   0.76,   0.22] sc=    0.425  <- OK
# (MERLION pid=1915) 18 w=[0.318,0.205,0.476] obj=[   0.20,   0.76,   0.20] sc=    0.315  <- OK
# (MERLION pid=1915) 19 w=[0.297,0.115,0.589] obj=[   0.20,   0.77,   0.37] sc=    0.367  <- OK
# (MERLION pid=1915) 20 w=[0.190,0.123,0.687] obj=[   0.21,   0.76,   0.24] sc=    0.301  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=731700
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 9) ===
# (MERLION pid=1915) 00 w=[0.577,0.423,0.000] obj=[   0.19,   0.76,   0.24] sc=    0.430  <- OK
# (MERLION pid=1915) 01 w=[0.373,0.347,0.279] obj=[   0.16,   0.78,   0.28] sc=    0.407  <- OK
# (MERLION pid=1915) 02 w=[0.155,0.023,0.823] obj=[   0.20,   0.77,   0.39] sc=    0.365  <- OK
# (MERLION pid=1915) 03 w=[0.326,0.247,0.427] obj=[   0.20,   0.76,   0.18] sc=    0.330  <- OK
# (MERLION pid=1915) 04 w=[0.234,0.303,0.463] obj=[   0.20,   0.76,   0.20] sc=    0.368  <- OK
# (MERLION pid=1915) 05 w=[0.474,0.352,0.174] obj=[   0.20,   0.77,   0.25] sc=    0.413  <- OK
# (MERLION pid=1915) 06 w=[0.139,0.152,0.709] obj=[   0.17,   0.76,   0.10] sc=    0.213  <- OK
# (MERLION pid=1915) 07 w=[0.403,0.282,0.315] obj=[   0.22,   0.76,   0.18] sc=    0.361  <- OK
# (MERLION pid=1915) 08 w=[0.098,0.184,0.719] obj=[   0.20,   0.76,   0.17] sc=    0.279  <- OK
# (MERLION pid=1915) 09 w=[0.352,0.267,0.382] obj=[   0.18,   0.76,   0.15] sc=    0.324  <- OK
# (MERLION pid=1915) 10 w=[0.305,0.216,0.479] obj=[   0.17,   0.77,   0.41] sc=    0.414  <- OK
# (MERLION pid=1915) 11 w=[0.309,0.238,0.453] obj=[   0.21,   0.76,   0.09] sc=    0.283  <- OK
# (MERLION pid=1915) 12 w=[0.527,0.380,0.092] obj=[   0.21,   0.76,   0.19] sc=    0.417  <- OK
# (MERLION pid=1915) 13 w=[0.067,0.138,0.794] obj=[   0.20,   0.77,   0.11] sc=    0.209  <- OK
# (MERLION pid=1915) 14 w=[0.086,0.083,0.831] obj=[   0.21,   0.75,   0.06] sc=    0.133  <- OK
# (MERLION pid=1915) 15 w=[0.314,0.229,0.457] obj=[   0.18,   0.76,   0.10] sc=    0.276  <- OK
# (MERLION pid=1915) 16 w=[0.135,0.177,0.688] obj=[   0.20,   0.76,   0.09] sc=    0.227  <- OK
# (MERLION pid=1915) 17 w=[0.499,0.285,0.216] obj=[   0.20,   0.76,   0.16] sc=    0.351  <- OK
# (MERLION pid=1915) 18 w=[0.447,0.270,0.284] obj=[   0.20,   0.77,   0.20] sc=    0.352  <- OK
# (MERLION pid=1915) 19 w=[0.349,0.365,0.286] obj=[   0.19,   0.75,   0.15] sc=    0.385  <- OK
# (MERLION pid=1915) 20 w=[0.280,0.451,0.269] obj=[   0.22,   0.77,   0.13] sc=    0.444  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=813000
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 10) ===
# (MERLION pid=1915) 00 w=[0.577,0.423,0.000] obj=[   0.21,   0.75,   0.13] sc=    0.441  <- OK
# (MERLION pid=1915) 01 w=[0.410,0.307,0.283] obj=[   0.18,   0.75,   0.26] sc=    0.380  <- OK
# (MERLION pid=1915) 02 w=[0.494,0.318,0.188] obj=[   0.17,   0.77,   0.39] sc=    0.402  <- OK
# (MERLION pid=1915) 03 w=[0.161,0.094,0.745] obj=[   0.18,   0.76,   0.15] sc=    0.211  <- OK
# (MERLION pid=1915) 04 w=[0.223,0.256,0.521] obj=[   0.22,   0.77,   0.15] sc=    0.326  <- OK
# (MERLION pid=1915) 05 w=[0.044,0.059,0.898] obj=[   0.16,   0.76,   0.32] sc=    0.343  <- OK
# (MERLION pid=1915) 06 w=[0.220,0.246,0.534] obj=[   0.19,   0.76,   0.21] sc=    0.340  <- OK
# (MERLION pid=1915) 07 w=[0.362,0.408,0.231] obj=[   0.19,   0.77,   0.14] sc=    0.416  <- OK
# (MERLION pid=1915) 08 w=[0.153,0.130,0.717] obj=[   0.18,   0.76,   0.38] sc=    0.395  <- OK
# (MERLION pid=1915) 09 w=[0.370,0.319,0.311] obj=[   0.20,   0.77,   0.11] sc=    0.357  <- OK
# (MERLION pid=1915) 10 w=[0.416,0.305,0.279] obj=[   0.17,   0.78,   0.13] sc=    0.345  <- OK
# (MERLION pid=1915) 11 w=[0.060,0.256,0.685] obj=[   0.20,   0.76,   0.26] sc=    0.383  <- OK
# (MERLION pid=1915) 12 w=[0.390,0.281,0.329] obj=[   0.19,   0.78,   0.35] sc=    0.407  <- OK
# (MERLION pid=1915) 13 w=[0.361,0.273,0.366] obj=[   0.20,   0.76,   0.13] sc=    0.327  <- OK
# (MERLION pid=1915) 14 w=[0.205,0.215,0.579] obj=[   0.19,   0.77,   0.39] sc=    0.430  <- OK
# (MERLION pid=1915) 15 w=[0.357,0.393,0.250] obj=[   0.20,   0.77,   0.09] sc=    0.397  <- OK
# (MERLION pid=1915) 16 w=[0.151,0.115,0.734] obj=[   0.17,   0.77,   0.26] sc=    0.302  <- OK
# (MERLION pid=1915) 17 w=[0.277,0.397,0.326] obj=[   0.23,   0.75,   0.12] sc=    0.401  <- OK
# (MERLION pid=1915) 18 w=[0.544,0.314,0.142] obj=[   0.17,   0.76,   0.18] sc=    0.357  <- OK
# (MERLION pid=1915) 19 w=[0.318,0.266,0.416] obj=[   0.20,   0.77,   0.34] sc=    0.411  <- OK
# (MERLION pid=1915) 20 w=[0.475,0.345,0.180] obj=[   0.20,   0.75,   0.18] sc=    0.386  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=894300
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 11) ===
# (MERLION pid=1915) 00 w=[0.044,0.059,0.898] obj=[   0.18,   0.77,   0.21] sc=    0.241  <- OK
# (MERLION pid=1915) 01 w=[0.085,0.119,0.796] obj=[   0.17,   0.77,   0.11] sc=    0.195  <- OK
# (MERLION pid=1915) 02 w=[0.225,0.236,0.539] obj=[   0.19,   0.76,   0.12] sc=    0.284  <- OK
# (MERLION pid=1915) 03 w=[0.443,0.263,0.294] obj=[   0.22,   0.76,   0.16] sc=    0.344  <- OK
# (MERLION pid=1915) 04 w=[0.566,0.434,0.000] obj=[   0.22,   0.75,   0.15] sc=    0.452  <- OK
# (MERLION pid=1915) 05 w=[0.231,0.187,0.582] obj=[   0.22,   0.76,   0.10] sc=    0.252  <- OK
# (MERLION pid=1915) 06 w=[0.175,0.250,0.575] obj=[   0.21,   0.76,   0.12] sc=    0.292  <- OK
# (MERLION pid=1915) 07 w=[0.249,0.239,0.512] obj=[   0.16,   0.77,   0.17] sc=    0.308  <- OK
# (MERLION pid=1915) 08 w=[0.277,0.178,0.545] obj=[   0.19,   0.76,   0.13] sc=    0.260  <- OK
# (MERLION pid=1915) 09 w=[0.173,0.181,0.645] obj=[   0.19,   0.76,   0.31] sc=    0.372  <- OK
# (MERLION pid=1915) 10 w=[0.105,0.045,0.850] obj=[   0.18,   0.78,   0.26] sc=    0.276  <- OK
# (MERLION pid=1915) 11 w=[0.184,0.153,0.662] obj=[   0.21,   0.77,   0.37] sc=    0.400  <- OK
# (MERLION pid=1915) 12 w=[0.334,0.231,0.434] obj=[   0.19,   0.77,   0.38] sc=    0.406  <- OK
# (MERLION pid=1915) 13 w=[0.444,0.318,0.238] obj=[   0.21,   0.75,   0.30] sc=    0.403  <- OK
# (MERLION pid=1915) 14 w=[0.346,0.321,0.333] obj=[   0.18,   0.76,   0.29] sc=    0.404  <- OK
# (MERLION pid=1915) 15 w=[0.224,0.272,0.504] obj=[   0.18,   0.76,   0.37] sc=    0.435  <- OK
# (MERLION pid=1915) 16 w=[0.338,0.254,0.408] obj=[   0.19,   0.76,   0.20] sc=    0.341  <- OK
# (MERLION pid=1915) 17 w=[0.311,0.328,0.361] obj=[   0.20,   0.77,   0.14] sc=    0.368  <- OK
# (MERLION pid=1915) 18 w=[0.441,0.356,0.203] obj=[   0.17,   0.76,   0.35] sc=    0.419  <- OK
# (MERLION pid=1915) 19 w=[0.226,0.036,0.737] obj=[   0.20,   0.77,   0.24] sc=    0.254  <- OK
# (MERLION pid=1915) 20 w=[0.139,0.163,0.698] obj=[   0.22,   0.76,   0.14] sc=    0.252  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=975600
# (MERLION pid=1915)
# (MERLION pid=1915) === POPULATION OBJECTIVE BREAKDOWN (Iter 12) ===
# (MERLION pid=1915) 00 w=[0.566,0.434,0.000] obj=[   0.19,   0.76,   0.15] sc=    0.439  <- OK
# (MERLION pid=1915) 01 w=[0.196,0.212,0.592] obj=[   0.21,   0.76,   0.15] sc=    0.290  <- OK
# (MERLION pid=1915) 02 w=[0.114,0.101,0.786] obj=[   0.20,   0.77,   0.12] sc=    0.193  <- OK
# (MERLION pid=1915) 03 w=[0.356,0.279,0.365] obj=[   0.19,   0.77,   0.13] sc=    0.327  <- OK
# (MERLION pid=1915) 04 w=[0.285,0.232,0.484] obj=[   0.21,   0.76,   0.39] sc=    0.424  <- OK
# (MERLION pid=1915) 05 w=[0.270,0.209,0.520] obj=[   0.17,   0.77,   0.24] sc=    0.331  <- OK
# (MERLION pid=1915) 06 w=[0.159,0.145,0.695] obj=[   0.20,   0.77,   0.13] sc=    0.234  <- OK
# (MERLION pid=1915) 07 w=[0.281,0.250,0.468] obj=[   0.22,   0.76,   0.17] sc=    0.334  <- OK
# (MERLION pid=1915) 08 w=[0.120,0.098,0.782] obj=[   0.22,   0.77,   0.25] sc=    0.292  <- OK
# (MERLION pid=1915) 09 w=[0.400,0.359,0.240] obj=[   0.24,   0.75,   0.16] sc=    0.406  <- OK
# (MERLION pid=1915) 10 w=[0.208,0.225,0.567] obj=[   0.22,   0.77,   0.22] sc=    0.343  <- OK
# (MERLION pid=1915) 11 w=[0.350,0.274,0.376] obj=[   0.20,   0.75,   0.28] sc=    0.384  <- OK
# (MERLION pid=1915) 12 w=[0.302,0.226,0.472] obj=[   0.19,   0.77,   0.15] sc=    0.302  <- OK
# (MERLION pid=1915) 13 w=[0.363,0.301,0.336] obj=[   0.19,   0.77,   0.33] sc=    0.410  <- OK
# (MERLION pid=1915) 14 w=[0.099,0.095,0.806] obj=[   0.17,   0.77,   0.14] sc=    0.204  <- OK
# (MERLION pid=1915) 15 w=[0.258,0.168,0.574] obj=[   0.17,   0.77,   0.15] sc=    0.259  <- OK
# (MERLION pid=1915) 16 w=[0.412,0.323,0.264] obj=[   0.18,   0.77,   0.11] sc=    0.348  <- OK
# (MERLION pid=1915) 17 w=[0.346,0.299,0.355] obj=[   0.20,   0.77,   0.17] sc=    0.360  <- OK
# (MERLION pid=1915) 18 w=[0.106,0.099,0.795] obj=[   0.18,   0.77,   0.35] sc=    0.374  <- OK
# (MERLION pid=1915) 19 w=[0.183,0.111,0.707] obj=[   0.20,   0.76,   0.14] sc=    0.216  <- OK
# (MERLION pid=1915) 20 w=[0.367,0.330,0.303] obj=[   0.22,   0.77,   0.18] sc=    0.386  <- OK
# (MERLION pid=1915) ================================================================
# (MERLION pid=1915) [MERLION] timesteps_this_iter=81300, timesteps_total=1056900
# 2026-02-19 05:43:48,522	INFO tune.py:798 -- Total run time: 5142.34 seconds (5141.70 seconds for the tuning loop).
# 2026-02-19 05:43:48,535	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2026-02-19 05:43:48,535	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2026-02-19 05:43:48,541	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2026-02-19 05:43:48,541	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=53223) 2026-02-19 05:43:51,529	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=53223) 2026-02-19 05:43:51,529	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=53223) 2026-02-19 05:43:51,529	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=53223) 2026-02-19 05:43:51,529	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 05:43:52,375	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2026-02-19 05:43:52,375	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2026-02-19 05:43:52,376	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 05:43:52,376	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 05:43:55,861	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# 2026-02-19 05:43:55,861	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# (RolloutWorker pid=53588) 2026-02-19 05:43:58,820	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=53588) 2026-02-19 05:43:58,820	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# ...
# (RolloutWorker pid=63103) 2026-02-19 11:39:04,621	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 11:39:05,356	INFO trainable.py:172 -- Trainable.setup took 11.039 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 11:39:05,357	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 9 ===
# (RolloutWorker pid=63716) 2026-02-19 12:23:48,690	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=63716) 2026-02-19 12:23:48,690	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=63716) 2026-02-19 12:23:48,690	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=63716) 2026-02-19 12:23:48,690	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=64074) 2026-02-19 12:23:56,069	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=64074) 2026-02-19 12:23:56,069	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=64074) 2026-02-19 12:23:56,069	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=64074) 2026-02-19 12:23:56,069	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 12:23:56,804	INFO trainable.py:172 -- Trainable.setup took 11.053 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 12:23:56,805	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 10 ===
# (RolloutWorker pid=64693) 2026-02-19 13:09:21,427	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=64693) 2026-02-19 13:09:21,427	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=64693) 2026-02-19 13:09:21,427	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=64693) 2026-02-19 13:09:21,427	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=65052) 2026-02-19 13:09:28,754	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=65052) 2026-02-19 13:09:28,754	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=65052) 2026-02-19 13:09:28,754	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=65052) 2026-02-19 13:09:28,754	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 13:09:29,488	INFO trainable.py:172 -- Trainable.setup took 11.040 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 13:09:29,489	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 11 ===
# (RolloutWorker pid=65672) 2026-02-19 13:54:59,795	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=65672) 2026-02-19 13:54:59,795	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=65672) 2026-02-19 13:54:59,795	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=65672) 2026-02-19 13:54:59,795	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=66031) 2026-02-19 13:55:07,106	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=66031) 2026-02-19 13:55:07,106	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=66031) 2026-02-19 13:55:07,106	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=66031) 2026-02-19 13:55:07,106	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 13:55:07,847	INFO trainable.py:172 -- Trainable.setup took 11.013 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 13:55:07,848	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 12 ===
# (RolloutWorker pid=66644) 2026-02-19 14:40:23,039	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=66644) 2026-02-19 14:40:23,039	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=66644) 2026-02-19 14:40:23,039	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=66644) 2026-02-19 14:40:23,039	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=67003) 2026-02-19 14:40:30,295	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=67003) 2026-02-19 14:40:30,295	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=67003) 2026-02-19 14:40:30,295	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=67003) 2026-02-19 14:40:30,295	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 14:40:31,030	INFO trainable.py:172 -- Trainable.setup took 11.034 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 14:40:31,031	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/.local/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:284: UserWarning: Path '/home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i012_m01' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# === Meta-policy 13 ===
# (RolloutWorker pid=67626) 2026-02-19 15:26:26,703	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=67626) 2026-02-19 15:26:26,703	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=67626) 2026-02-19 15:26:26,703	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=67626) 2026-02-19 15:26:26,703	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=67985) 2026-02-19 15:26:33,987	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=67985) 2026-02-19 15:26:33,987	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=67985) 2026-02-19 15:26:33,987	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=67985) 2026-02-19 15:26:33,987	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 15:26:34,745	INFO trainable.py:172 -- Trainable.setup took 11.023 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 15:26:34,746	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.

# %% [markdown]
# #### TO TRY NEXT:
# * Narrowing the profit range for normalisation >> hopefully when the the agent sees the profit has bigger portion, it affects more to the final rewards, then the agent will consider to put more weights into profit!
#
# #### NOTE, My observation on MERLION behaviour:
# It tends to increase the reward on the reward vector value that contributes more in the final scalar reward, which is expected. Consequently, it is sensitive to normalisation range. If we set normalisation range too broad --> initial reard contribution in the beginning will be low --> Merlion thinks that this reward has less significant impact to final scalar reward --> allocate the weights to other reward vector values and decreases the weight for this one.

# %% [markdown]
# ### METAMORL
# timesteps = W (S + 1) H
#
# ### MERLION
# H = max(timestep/episode, rollout_fragment_length)
# S = inner_adaptation_steps
# W = num_rollout_workers
# P = population_size
# J = meta_batch_size
#
# timesteps = W (S + 1) H + P (J (S + 1) H + H)
#             {metaMORL-like} {population-stage}
#
# A timestep represents an agent-environment interaction sampling.
#
# In MERLION, the task batch size is defined in meta_batch_size, while num_rollout_workers only determine the parallel computation for speed. In Metamorl, the n_tasks is defined based on num_rollout_worker, so it is attached to the core number used.
#
# In MERLION, the iteration is calculated for the overall population, hence each individual solution learns much less iteration than Metamorl. The justification is because each individual solution learns locally, focusing within narrower search space.
#
# ### How the iteration works:
#
# each MERLION individual θᵢ gets fewer total updates than the single MetaMORL meta-policy,
#
# “each individual solution learns locally, focusing within a narrower search space”
#
# because the sample budget is spread across many individuals rather than concentrated on one.
#
# So:
#
# As a theoretical / structural statement: say
#
# “Per global iteration, MERLION trains all individuals; cost scales with P×meta_batch_size.”
#
# As a fair-sample comparison statement: say
#
# “For a fixed environment step budget, each MERLION individual effectively sees fewer updates than a single MetaMORL meta-policy, trading depth per policy for coverage/diversity across the population.”
#
# PS: Total running time in MERLION might more than MetaMORL since aside from metapolicy update (inner and outer), it also involves weight update thru evolutionary mechanism.
#
# NOTE: Currently, MERLION still contains MetaMORL-like update which is actually algorithmically unnecessary but needed. Hence, these stage can be ignored for iteration and timing.
#
# What happens if you “remove Phase 1”? If by “remove Phase 1” you mean: delete inner_adaptation_steps transform, stop producing (samples, metrics_dict), and leave MERLIONMetaUpdate.__call__ untouched,
#
# then:
#
# data_tuple will no longer be a 2-tuple, _shared_samples = data_tuple[0] will be wrong, you’ll get shape/TypeErrors → so yes, bugs.
#
# This is not because of Ray API, but because your execution_plan and MERLIONMetaUpdate are coupled.
#
# #### For now, let's just do interpolation to ignore MetaMORL update and upgrade version later maybe.

# %% [markdown]
# ### Try to fine-tune using stable-baselines3

# %%
from stable_baselines3 import PPO
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from _merlion.fine_tuning.ft_complex_env_merlion import TestComplexSC
from _metamorl.algo_ray.rllib.algorithms.maml import merlion_finetuning_sb3_independent as ft

# %%
# (Re)start Ray cleanly
ray.shutdown()
ray.init(ignore_reinit_error=True, include_dashboard=False)

def make_env_ray(config):
    """
    RLlib factory: receives a dict `config` and must return a *Gymnasium Env instance*.
    We wrap with TimeLimit here so both RLlib and Gym share the same horizon behavior.
    """
    base = TestComplexSC(**config)            # pass config keys into your env
    max_steps = int(config.get("max_steps", 100))
    return TimeLimit(base, max_episode_steps=max_steps)

register_env("testSC", make_env_ray)
register_env("complex_sc", lambda cfg: complex_env_merlion.make_env(cfg)) # register meta-env
# Out:
# 2026-02-21 22:37:00,176	WARNING utils.py:640 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2026-02-21 22:37:00,177	WARNING utils.py:652 -- Ray currently does not support initializing Raywith fractional cpus. Your num_cpus will be truncated from 13.68 to 13.
# 2026-02-21 22:37:00,179	WARNING services.py:1780 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2026-02-21 22:37:00,216	INFO worker.py:1553 -- Started a local Ray instance.

# %%
# Optional: re-register safely if re-running cells
try:
    gym.spec("testSC")  # raises if not registered
    # Gymnasium 0.29.x: remove existing spec to allow re-register
    del gym.envs.registration.registry["testSC"]
except Exception:
    pass

def make_env_gym(**kwargs):
    base = TestComplexSC(**kwargs)
    max_steps = int(kwargs.get("max_steps", 100))
    return TimeLimit(base, max_episode_steps=max_steps)

gym.register(
    id="testSC",
    entry_point=make_env_gym,   # callable that returns an Env
)

# %% [markdown]
# Finetuning timesteps = P x (M + 1) x K x W
#
# P: population size
#
# M: number of local perturbation
#
# K: env steps per perturbation
#
# W: rollout workers

# %%
#finetuning timesteps = 10 x 5 x 100 x 1 = 5000 timesteps
k=6

start_time = time.time()
ft.finetune_with_local_perturbations(
    pop_dir=f"/home/rifnyrachman7/_merlion/training_data/complex_sc_v0/metapolicies-{k}",
    env_id="testSC",
    out_dir=f"/home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-{k}",
    total_steps=20000, # default 5000
    record_every=512, # default 1
    eval_episodes=50, # default 50
    m_perturb=2,
    eps=0.05,
    seed=7,
    skip_existing=True,
)
end_time = time.time()
print(f"fine-tuning run-{k}:",end_time - start_time,"seconds")
# Out:
# 2026-02-19 19:46:19,343	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2026-02-19 19:46:19,343	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2026-02-19 19:46:19,359	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2026-02-19 19:46:19,359	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# === Meta-policy 0 ===
# (RolloutWorker pid=79693) 2026-02-19 19:46:22,572	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=79693) 2026-02-19 19:46:22,572	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=79693) 2026-02-19 19:46:22,572	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=79693) 2026-02-19 19:46:22,572	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:46:23,443	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2026-02-19 19:46:23,443	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2026-02-19 19:46:23,444	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:46:23,444	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:46:27,632	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# 2026-02-19 19:46:27,632	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# (RolloutWorker pid=80116) 2026-02-19 19:46:30,763	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80116) 2026-02-19 19:46:30,763	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80116) 2026-02-19 19:46:30,763	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=80116) 2026-02-19 19:46:30,763	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:46:31,517	INFO trainable.py:172 -- Trainable.setup took 12.159 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:46:31,518	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i000_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i000_m-1 already exists, loading existing results into summaries.
# [skip+load] i000_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i000_m00 already exists, loading existing results into summaries.
# [skip+load] i000_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i000_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 1 ===
# (RolloutWorker pid=80195) 2026-02-19 19:46:35,271	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80195) 2026-02-19 19:46:35,271	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80195) 2026-02-19 19:46:35,271	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=80195) 2026-02-19 19:46:35,271	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=80554) 2026-02-19 19:46:42,776	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80554) 2026-02-19 19:46:42,776	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80554) 2026-02-19 19:46:42,776	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=80554) 2026-02-19 19:46:42,776	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:46:43,539	INFO trainable.py:172 -- Trainable.setup took 11.297 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:46:43,541	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i001_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i001_m-1 already exists, loading existing results into summaries.
# [skip+load] i001_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i001_m00 already exists, loading existing results into summaries.
# [skip+load] i001_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i001_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 2 ===
# (RolloutWorker pid=80625) 2026-02-19 19:46:47,290	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80625) 2026-02-19 19:46:47,290	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80625) 2026-02-19 19:46:47,290	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=80625) 2026-02-19 19:46:47,290	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=80983) 2026-02-19 19:46:54,852	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80983) 2026-02-19 19:46:54,852	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=80983) 2026-02-19 19:46:54,852	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=80983) 2026-02-19 19:46:54,852	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:46:55,611	INFO trainable.py:172 -- Trainable.setup took 11.353 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:46:55,612	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i002_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i002_m-1 already exists, loading existing results into summaries.
# [skip+load] i002_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i002_m00 already exists, loading existing results into summaries.
# [skip+load] i002_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i002_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 3 ===
# (RolloutWorker pid=81054) 2026-02-19 19:46:59,363	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81054) 2026-02-19 19:46:59,363	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81054) 2026-02-19 19:46:59,363	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=81054) 2026-02-19 19:46:59,363	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=81413) 2026-02-19 19:47:06,971	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81413) 2026-02-19 19:47:06,971	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81413) 2026-02-19 19:47:06,971	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=81413) 2026-02-19 19:47:06,971	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:47:07,723	INFO trainable.py:172 -- Trainable.setup took 11.393 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:47:07,724	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i003_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i003_m-1 already exists, loading existing results into summaries.
# [skip+load] i003_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i003_m00 already exists, loading existing results into summaries.
# [skip+load] i003_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i003_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 4 ===
# (RolloutWorker pid=81484) 2026-02-19 19:47:11,501	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81484) 2026-02-19 19:47:11,501	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81484) 2026-02-19 19:47:11,501	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=81484) 2026-02-19 19:47:11,501	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=81842) 2026-02-19 19:47:19,021	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81842) 2026-02-19 19:47:19,021	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81842) 2026-02-19 19:47:19,021	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=81842) 2026-02-19 19:47:19,021	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:47:19,771	INFO trainable.py:172 -- Trainable.setup took 11.330 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:47:19,772	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i004_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i004_m-1 already exists, loading existing results into summaries.
# [skip+load] i004_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i004_m00 already exists, loading existing results into summaries.
# [skip+load] i004_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i004_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 5 ===
# (RolloutWorker pid=81917) 2026-02-19 19:47:23,623	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81917) 2026-02-19 19:47:23,623	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=81917) 2026-02-19 19:47:23,623	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=81917) 2026-02-19 19:47:23,623	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=82290) 2026-02-19 19:47:31,177	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=82290) 2026-02-19 19:47:31,177	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=82290) 2026-02-19 19:47:31,178	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=82290) 2026-02-19 19:47:31,178	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:47:31,944	INFO trainable.py:172 -- Trainable.setup took 11.452 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:47:31,945	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i005_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i005_m-1 already exists, loading existing results into summaries.
# [skip+load] i005_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i005_m00 already exists, loading existing results into summaries.
# [skip+load] i005_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i005_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 6 ===
# (RolloutWorker pid=82361) 2026-02-19 19:47:35,737	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=82361) 2026-02-19 19:47:35,737	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=82361) 2026-02-19 19:47:35,738	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=82361) 2026-02-19 19:47:35,738	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=82720) 2026-02-19 19:47:43,582	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=82720) 2026-02-19 19:47:43,582	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=82720) 2026-02-19 19:47:43,582	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=82720) 2026-02-19 19:47:43,582	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:47:44,342	INFO trainable.py:172 -- Trainable.setup took 11.678 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:47:44,343	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i006_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i006_m-1 already exists, loading existing results into summaries.
# [skip+load] i006_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i006_m00 already exists, loading existing results into summaries.
# [skip+load] i006_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i006_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 7 ===
# (RolloutWorker pid=82791) 2026-02-19 19:47:48,226	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=82791) 2026-02-19 19:47:48,226	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=82791) 2026-02-19 19:47:48,226	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=82791) 2026-02-19 19:47:48,226	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=83149) 2026-02-19 19:47:55,899	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=83149) 2026-02-19 19:47:55,899	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=83149) 2026-02-19 19:47:55,899	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=83149) 2026-02-19 19:47:55,899	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:47:56,653	INFO trainable.py:172 -- Trainable.setup took 11.511 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:47:56,655	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i007_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i007_m-1 already exists, loading existing results into summaries.
# [skip+load] i007_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i007_m00 already exists, loading existing results into summaries.
# [skip+load] i007_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i007_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 8 ===
# (RolloutWorker pid=83221) 2026-02-19 19:48:00,402	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=83221) 2026-02-19 19:48:00,402	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=83221) 2026-02-19 19:48:00,402	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=83221) 2026-02-19 19:48:00,402	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=83580) 2026-02-19 19:48:08,059	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=83580) 2026-02-19 19:48:08,059	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=83580) 2026-02-19 19:48:08,060	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=83580) 2026-02-19 19:48:08,060	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:48:08,797	INFO trainable.py:172 -- Trainable.setup took 11.425 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:48:08,799	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i008_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i008_m-1 already exists, loading existing results into summaries.
# [skip+load] i008_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i008_m00 already exists, loading existing results into summaries.
# [skip+load] i008_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i008_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 9 ===
# (RolloutWorker pid=83651) 2026-02-19 19:48:12,623	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=83651) 2026-02-19 19:48:12,623	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=83651) 2026-02-19 19:48:12,623	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=83651) 2026-02-19 19:48:12,623	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84009) 2026-02-19 19:48:20,256	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84009) 2026-02-19 19:48:20,256	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84009) 2026-02-19 19:48:20,257	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84009) 2026-02-19 19:48:20,257	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:48:21,013	INFO trainable.py:172 -- Trainable.setup took 11.497 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:48:21,014	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i009_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i009_m-1 already exists, loading existing results into summaries.
# [skip+load] i009_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i009_m00 already exists, loading existing results into summaries.
# [skip+load] i009_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i009_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 10 ===
# (RolloutWorker pid=84080) 2026-02-19 19:48:24,811	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84080) 2026-02-19 19:48:24,811	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84080) 2026-02-19 19:48:24,811	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84080) 2026-02-19 19:48:24,811	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84439) 2026-02-19 19:48:32,311	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84439) 2026-02-19 19:48:32,311	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84439) 2026-02-19 19:48:32,311	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84439) 2026-02-19 19:48:32,311	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:48:33,050	INFO trainable.py:172 -- Trainable.setup took 11.315 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:48:33,051	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i010_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i010_m-1 already exists, loading existing results into summaries.
# [skip+load] i010_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i010_m00 already exists, loading existing results into summaries.
# [skip+load] i010_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i010_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 11 ===
# (RolloutWorker pid=84510) 2026-02-19 19:48:36,790	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84510) 2026-02-19 19:48:36,790	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84510) 2026-02-19 19:48:36,791	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84510) 2026-02-19 19:48:36,791	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84869) 2026-02-19 19:48:44,545	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84869) 2026-02-19 19:48:44,545	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84869) 2026-02-19 19:48:44,545	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84869) 2026-02-19 19:48:44,545	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:48:45,291	INFO trainable.py:172 -- Trainable.setup took 11.521 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:48:45,292	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i011_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i011_m-1 already exists, loading existing results into summaries.
# [skip+load] i011_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i011_m00 already exists, loading existing results into summaries.
# [skip+load] i011_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i011_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 12 ===
# (RolloutWorker pid=84940) 2026-02-19 19:48:49,065	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84940) 2026-02-19 19:48:49,065	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=84940) 2026-02-19 19:48:49,065	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=84940) 2026-02-19 19:48:49,065	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=85299) 2026-02-19 19:48:56,400	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=85299) 2026-02-19 19:48:56,400	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=85299) 2026-02-19 19:48:56,400	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=85299) 2026-02-19 19:48:56,400	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:48:57,144	INFO trainable.py:172 -- Trainable.setup took 11.132 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:48:57,145	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i012_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i012_m-1 already exists, loading existing results into summaries.
# [skip+load] i012_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i012_m00 already exists, loading existing results into summaries.
# [skip+load] i012_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i012_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 13 ===
# (RolloutWorker pid=85369) 2026-02-19 19:49:00,887	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=85369) 2026-02-19 19:49:00,887	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=85369) 2026-02-19 19:49:00,887	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=85369) 2026-02-19 19:49:00,887	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=85728) 2026-02-19 19:49:08,253	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=85728) 2026-02-19 19:49:08,253	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=85728) 2026-02-19 19:49:08,253	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=85728) 2026-02-19 19:49:08,253	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:49:08,985	INFO trainable.py:172 -- Trainable.setup took 11.121 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:49:08,986	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i013_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i013_m-1 already exists, loading existing results into summaries.
# [skip+load] i013_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i013_m00 already exists, loading existing results into summaries.
# [skip+load] i013_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i013_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 14 ===
# (RolloutWorker pid=85799) 2026-02-19 19:49:12,839	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=85799) 2026-02-19 19:49:12,839	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=85799) 2026-02-19 19:49:12,840	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=85799) 2026-02-19 19:49:12,840	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=86157) 2026-02-19 19:49:20,160	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=86157) 2026-02-19 19:49:20,160	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=86157) 2026-02-19 19:49:20,160	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=86157) 2026-02-19 19:49:20,160	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:49:20,902	INFO trainable.py:172 -- Trainable.setup took 11.198 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:49:20,903	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i014_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i014_m-1 already exists, loading existing results into summaries.
# [skip+load] i014_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i014_m00 already exists, loading existing results into summaries.
# [skip+load] i014_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i014_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 15 ===
# (RolloutWorker pid=86231) 2026-02-19 19:49:24,685	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=86231) 2026-02-19 19:49:24,685	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=86231) 2026-02-19 19:49:24,686	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=86231) 2026-02-19 19:49:24,686	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=86605) 2026-02-19 19:49:32,218	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=86605) 2026-02-19 19:49:32,218	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=86605) 2026-02-19 19:49:32,218	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=86605) 2026-02-19 19:49:32,218	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:49:32,972	INFO trainable.py:172 -- Trainable.setup took 11.338 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:49:32,973	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i015_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i015_m-1 already exists, loading existing results into summaries.
# [skip+load] i015_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i015_m00 already exists, loading existing results into summaries.
# [skip+load] i015_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i015_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 16 ===
# (RolloutWorker pid=86676) 2026-02-19 19:49:36,799	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=86676) 2026-02-19 19:49:36,799	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=86676) 2026-02-19 19:49:36,799	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=86676) 2026-02-19 19:49:36,799	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=87034) 2026-02-19 19:49:44,312	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87034) 2026-02-19 19:49:44,312	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87034) 2026-02-19 19:49:44,312	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=87034) 2026-02-19 19:49:44,312	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:49:45,079	INFO trainable.py:172 -- Trainable.setup took 11.378 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:49:45,080	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i016_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i016_m-1 already exists, loading existing results into summaries.
# [skip+load] i016_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i016_m00 already exists, loading existing results into summaries.
# [skip+load] i016_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i016_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 17 ===
# (RolloutWorker pid=87105) 2026-02-19 19:49:48,896	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87105) 2026-02-19 19:49:48,896	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87105) 2026-02-19 19:49:48,897	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=87105) 2026-02-19 19:49:48,897	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=87464) 2026-02-19 19:49:56,649	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87464) 2026-02-19 19:49:56,649	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87464) 2026-02-19 19:49:56,649	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=87464) 2026-02-19 19:49:56,649	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:49:57,396	INFO trainable.py:172 -- Trainable.setup took 11.598 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:49:57,397	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i017_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i017_m-1 already exists, loading existing results into summaries.
# [skip+load] i017_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i017_m00 already exists, loading existing results into summaries.
# [skip+load] i017_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i017_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 18 ===
# (RolloutWorker pid=87534) 2026-02-19 19:50:01,202	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87534) 2026-02-19 19:50:01,202	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87534) 2026-02-19 19:50:01,203	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=87534) 2026-02-19 19:50:01,203	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=87893) 2026-02-19 19:50:08,630	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87893) 2026-02-19 19:50:08,630	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=87893) 2026-02-19 19:50:08,630	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=87893) 2026-02-19 19:50:08,630	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 19:50:09,365	INFO trainable.py:172 -- Trainable.setup took 11.234 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 19:50:09,366	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i018_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/i018_m-1 already exists, loading existing results into summaries.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 19 ===
# (RolloutWorker pid=88408) 2026-02-19 20:20:41,526	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=88408) 2026-02-19 20:20:41,526	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=88408) 2026-02-19 20:20:41,526	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=88408) 2026-02-19 20:20:41,526	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=88767) 2026-02-19 20:20:49,001	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=88767) 2026-02-19 20:20:49,001	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=88767) 2026-02-19 20:20:49,001	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=88767) 2026-02-19 20:20:49,001	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 20:20:49,736	INFO trainable.py:172 -- Trainable.setup took 11.305 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 20:20:49,738	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 20 ===
# (RolloutWorker pid=89448) 2026-02-19 21:06:18,709	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=89448) 2026-02-19 21:06:18,709	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=89448) 2026-02-19 21:06:18,709	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=89448) 2026-02-19 21:06:18,709	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=89809) 2026-02-19 21:06:29,439	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=89809) 2026-02-19 21:06:29,439	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=89809) 2026-02-19 21:06:29,439	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=89809) 2026-02-19 21:06:29,439	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-19 21:06:30,170	INFO trainable.py:172 -- Trainable.setup took 14.470 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-19 21:06:30,171	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# Saved:
# - /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/all_offspring_summary.csv
# - /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-6/all_timesteps_long.csv
#
# fine-tuning run-6: 7540.729987859726 seconds

# %%
#finetuning timesteps = 10 x 5 x 100 x 1 = 5000 timesteps
runs = [1, 7]
for k in runs:
    start_time = time.time()
    ft.finetune_with_local_perturbations(
        pop_dir=f"/home/rifnyrachman7/_merlion/training_data/complex_sc_v0/metapolicies-{k}",
        env_id="testSC",
        out_dir=f"/home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-{k}",
        total_steps=20000, # default 5000
        record_every=512, # default 1
        eval_episodes=50, # default 50
        m_perturb=2,
        eps=0.05,
        seed=7,
        skip_existing=True,
    )
    end_time = time.time()
    print(f"fine-tuning run-{k}:",end_time - start_time,"seconds")
# Out:
# 2026-02-17 15:58:59,078	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2026-02-17 15:58:59,078	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2026-02-17 15:58:59,117	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2026-02-17 15:58:59,117	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# === Meta-policy 0 ===
# (RolloutWorker pid=2852) 2026-02-17 15:59:02,234	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=2852) 2026-02-17 15:59:02,234	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=2852) 2026-02-17 15:59:02,234	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=2852) 2026-02-17 15:59:02,234	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 15:59:03,426	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2026-02-17 15:59:03,426	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2026-02-17 15:59:03,427	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 15:59:03,427	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 15:59:07,453	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# 2026-02-17 15:59:07,453	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# (RolloutWorker pid=3275) 2026-02-17 15:59:10,442	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3275) 2026-02-17 15:59:10,442	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3275) 2026-02-17 15:59:10,442	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3275) 2026-02-17 15:59:10,442	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 15:59:11,171	INFO trainable.py:172 -- Trainable.setup took 12.055 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 15:59:11,172	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i000_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i000_m-1 already exists, loading existing results into summaries.
# [skip+load] i000_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i000_m00 already exists, loading existing results into summaries.
# [skip+load] i000_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i000_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 1 ===
# (RolloutWorker pid=3354) 2026-02-17 15:59:14,860	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3354) 2026-02-17 15:59:14,860	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3354) 2026-02-17 15:59:14,860	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3354) 2026-02-17 15:59:14,860	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3713) 2026-02-17 15:59:22,380	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3713) 2026-02-17 15:59:22,380	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3713) 2026-02-17 15:59:22,380	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3713) 2026-02-17 15:59:22,380	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 15:59:23,104	INFO trainable.py:172 -- Trainable.setup took 11.204 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 15:59:23,105	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i001_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i001_m-1 already exists, loading existing results into summaries.
# [skip+load] i001_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i001_m00 already exists, loading existing results into summaries.
# [skip+load] i001_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i001_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 2 ===
# (RolloutWorker pid=3784) 2026-02-17 15:59:26,790	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3784) 2026-02-17 15:59:26,790	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3784) 2026-02-17 15:59:26,790	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3784) 2026-02-17 15:59:26,790	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4142) 2026-02-17 15:59:34,056	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4142) 2026-02-17 15:59:34,056	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4142) 2026-02-17 15:59:34,056	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4142) 2026-02-17 15:59:34,056	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 15:59:34,789	INFO trainable.py:172 -- Trainable.setup took 10.959 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 15:59:34,790	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i002_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i002_m-1 already exists, loading existing results into summaries.
# [skip+load] i002_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i002_m00 already exists, loading existing results into summaries.
# [skip+load] i002_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i002_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 3 ===
# (RolloutWorker pid=4213) 2026-02-17 15:59:38,507	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4213) 2026-02-17 15:59:38,507	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4213) 2026-02-17 15:59:38,507	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4213) 2026-02-17 15:59:38,507	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4572) 2026-02-17 15:59:45,810	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4572) 2026-02-17 15:59:45,810	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4572) 2026-02-17 15:59:45,810	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4572) 2026-02-17 15:59:45,810	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 15:59:46,534	INFO trainable.py:172 -- Trainable.setup took 11.019 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 15:59:46,535	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i003_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i003_m-1 already exists, loading existing results into summaries.
# [skip+load] i003_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i003_m00 already exists, loading existing results into summaries.
# [skip+load] i003_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i003_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 4 ===
# (RolloutWorker pid=4642) 2026-02-17 15:59:50,290	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4642) 2026-02-17 15:59:50,290	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4642) 2026-02-17 15:59:50,290	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4642) 2026-02-17 15:59:50,290	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5001) 2026-02-17 15:59:57,563	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5001) 2026-02-17 15:59:57,563	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5001) 2026-02-17 15:59:57,563	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5001) 2026-02-17 15:59:57,563	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 15:59:58,293	INFO trainable.py:172 -- Trainable.setup took 11.033 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 15:59:58,294	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i004_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i004_m-1 already exists, loading existing results into summaries.
# [skip+load] i004_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i004_m00 already exists, loading existing results into summaries.
# [skip+load] i004_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i004_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 5 ===
# (RolloutWorker pid=5072) 2026-02-17 16:00:02,027	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5072) 2026-02-17 16:00:02,027	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5072) 2026-02-17 16:00:02,027	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5072) 2026-02-17 16:00:02,027	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5430) 2026-02-17 16:00:09,301	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5430) 2026-02-17 16:00:09,301	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5430) 2026-02-17 16:00:09,301	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5430) 2026-02-17 16:00:09,301	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:00:10,025	INFO trainable.py:172 -- Trainable.setup took 11.005 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:00:10,027	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i005_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i005_m-1 already exists, loading existing results into summaries.
# [skip+load] i005_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i005_m00 already exists, loading existing results into summaries.
# [skip+load] i005_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i005_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 6 ===
# (RolloutWorker pid=5501) 2026-02-17 16:00:13,736	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5501) 2026-02-17 16:00:13,736	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5501) 2026-02-17 16:00:13,736	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5501) 2026-02-17 16:00:13,736	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5860) 2026-02-17 16:00:21,186	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5860) 2026-02-17 16:00:21,186	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5860) 2026-02-17 16:00:21,186	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5860) 2026-02-17 16:00:21,186	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:00:21,915	INFO trainable.py:172 -- Trainable.setup took 11.159 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:00:21,916	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i006_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i006_m-1 already exists, loading existing results into summaries.
# [skip+load] i006_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i006_m00 already exists, loading existing results into summaries.
# [skip+load] i006_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i006_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 7 ===
# (RolloutWorker pid=5930) 2026-02-17 16:00:25,677	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5930) 2026-02-17 16:00:25,677	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5930) 2026-02-17 16:00:25,677	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5930) 2026-02-17 16:00:25,677	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6307) 2026-02-17 16:00:33,121	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6307) 2026-02-17 16:00:33,121	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6307) 2026-02-17 16:00:33,122	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6307) 2026-02-17 16:00:33,122	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:00:33,850	INFO trainable.py:172 -- Trainable.setup took 11.152 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:00:33,851	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i007_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i007_m-1 already exists, loading existing results into summaries.
# [skip+load] i007_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i007_m00 already exists, loading existing results into summaries.
# [skip+load] i007_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i007_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 8 ===
# (RolloutWorker pid=6378) 2026-02-17 16:00:37,645	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6378) 2026-02-17 16:00:37,645	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6378) 2026-02-17 16:00:37,645	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6378) 2026-02-17 16:00:37,645	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6736) 2026-02-17 16:00:45,106	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6736) 2026-02-17 16:00:45,106	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6736) 2026-02-17 16:00:45,106	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6736) 2026-02-17 16:00:45,106	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:00:45,848	INFO trainable.py:172 -- Trainable.setup took 11.270 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:00:45,849	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i008_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i008_m-1 already exists, loading existing results into summaries.
# [skip+load] i008_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i008_m00 already exists, loading existing results into summaries.
# [skip+load] i008_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i008_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 9 ===
# (RolloutWorker pid=6807) 2026-02-17 16:00:49,590	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6807) 2026-02-17 16:00:49,590	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6807) 2026-02-17 16:00:49,590	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6807) 2026-02-17 16:00:49,590	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7166) 2026-02-17 16:00:57,003	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7166) 2026-02-17 16:00:57,003	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7166) 2026-02-17 16:00:57,003	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7166) 2026-02-17 16:00:57,003	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:00:57,732	INFO trainable.py:172 -- Trainable.setup took 11.158 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:00:57,733	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i009_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i009_m-1 already exists, loading existing results into summaries.
# [skip+load] i009_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i009_m00 already exists, loading existing results into summaries.
# [skip+load] i009_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i009_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 10 ===
# (RolloutWorker pid=7237) 2026-02-17 16:01:01,512	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7237) 2026-02-17 16:01:01,512	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7237) 2026-02-17 16:01:01,512	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7237) 2026-02-17 16:01:01,512	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7595) 2026-02-17 16:01:08,769	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7595) 2026-02-17 16:01:08,769	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7595) 2026-02-17 16:01:08,769	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7595) 2026-02-17 16:01:08,769	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:01:09,500	INFO trainable.py:172 -- Trainable.setup took 11.038 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:01:09,501	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i010_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i010_m-1 already exists, loading existing results into summaries.
# [skip+load] i010_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i010_m00 already exists, loading existing results into summaries.
# [skip+load] i010_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i010_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 11 ===
# (RolloutWorker pid=7666) 2026-02-17 16:01:13,312	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7666) 2026-02-17 16:01:13,312	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7666) 2026-02-17 16:01:13,312	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7666) 2026-02-17 16:01:13,312	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8025) 2026-02-17 16:01:20,936	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8025) 2026-02-17 16:01:20,936	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8025) 2026-02-17 16:01:20,936	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8025) 2026-02-17 16:01:20,936	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:01:21,661	INFO trainable.py:172 -- Trainable.setup took 11.429 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:01:21,662	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i011_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i011_m-1 already exists, loading existing results into summaries.
# [skip+load] i011_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i011_m00 already exists, loading existing results into summaries.
# [skip+load] i011_m01: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i011_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 12 ===
# (RolloutWorker pid=8095) 2026-02-17 16:01:25,438	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8095) 2026-02-17 16:01:25,438	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8095) 2026-02-17 16:01:25,438	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8095) 2026-02-17 16:01:25,438	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8454) 2026-02-17 16:01:32,774	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8454) 2026-02-17 16:01:32,774	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8454) 2026-02-17 16:01:32,774	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8454) 2026-02-17 16:01:32,774	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:01:33,497	INFO trainable.py:172 -- Trainable.setup took 11.107 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:01:33,498	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i012_m-1: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i012_m-1 already exists, loading existing results into summaries.
# [skip+load] i012_m00: /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/i012_m00 already exists, loading existing results into summaries.
#   [warn] weight.json missing, using w_im from schedule.
#   [warn] learning_curve.csv not found; offspring not added to summary.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# === Meta-policy 13 ===
# (RolloutWorker pid=8754) 2026-02-17 16:16:12,962	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8754) 2026-02-17 16:16:12,962	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8754) 2026-02-17 16:16:12,962	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8754) 2026-02-17 16:16:12,962	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=9112) 2026-02-17 16:16:20,275	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9112) 2026-02-17 16:16:20,275	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9112) 2026-02-17 16:16:20,275	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=9112) 2026-02-17 16:16:20,275	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 16:16:21,000	INFO trainable.py:172 -- Trainable.setup took 10.994 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 16:16:21,002	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 14 ===
# (RolloutWorker pid=9779) 2026-02-17 17:00:36,784	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9779) 2026-02-17 17:00:36,784	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9779) 2026-02-17 17:00:36,785	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=9779) 2026-02-17 17:00:36,785	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=10138) 2026-02-17 17:00:44,005	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10138) 2026-02-17 17:00:44,005	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10138) 2026-02-17 17:00:44,005	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=10138) 2026-02-17 17:00:44,005	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 17:00:44,731	INFO trainable.py:172 -- Trainable.setup took 10.881 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 17:00:44,732	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 15 ===
# (RolloutWorker pid=10802) 2026-02-17 17:44:48,275	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10802) 2026-02-17 17:44:48,275	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10802) 2026-02-17 17:44:48,275	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=10802) 2026-02-17 17:44:48,275	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=11161) 2026-02-17 17:44:55,419	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=11161) 2026-02-17 17:44:55,419	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=11161) 2026-02-17 17:44:55,419	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=11161) 2026-02-17 17:44:55,419	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 17:44:56,141	INFO trainable.py:172 -- Trainable.setup took 10.805 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 17:44:56,143	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 16 ===
# (RolloutWorker pid=11832) 2026-02-17 18:29:11,204	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=11832) 2026-02-17 18:29:11,204	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# ...
# (RolloutWorker pid=16307) 2026-02-17 21:28:21,587	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 21:28:22,309	INFO trainable.py:172 -- Trainable.setup took 10.867 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 21:28:22,310	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# Saved:
# - /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/all_offspring_summary.csv
# - /home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-1/all_timesteps_long.csv
#
# fine-tuning run-1: 22475.952778100967 seconds
#
# === Meta-policy 0 ===
# (RolloutWorker pid=16967) 2026-02-17 22:13:38,031	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=16967) 2026-02-17 22:13:38,031	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=16967) 2026-02-17 22:13:38,032	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=16967) 2026-02-17 22:13:38,032	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=17326) 2026-02-17 22:13:45,261	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=17326) 2026-02-17 22:13:45,261	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=17326) 2026-02-17 22:13:45,261	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=17326) 2026-02-17 22:13:45,261	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 22:13:45,987	INFO trainable.py:172 -- Trainable.setup took 10.951 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 22:13:45,988	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 1 ===
# (RolloutWorker pid=17941) 2026-02-17 22:58:38,699	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=17941) 2026-02-17 22:58:38,699	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=17941) 2026-02-17 22:58:38,699	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=17941) 2026-02-17 22:58:38,699	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=18299) 2026-02-17 22:58:45,922	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=18299) 2026-02-17 22:58:45,922	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=18299) 2026-02-17 22:58:45,922	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=18299) 2026-02-17 22:58:45,922	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 22:58:46,653	INFO trainable.py:172 -- Trainable.setup took 10.891 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 22:58:46,654	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 2 ===
# (RolloutWorker pid=18948) 2026-02-17 23:44:20,948	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=18948) 2026-02-17 23:44:20,948	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=18948) 2026-02-17 23:44:20,948	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=18948) 2026-02-17 23:44:20,948	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=19306) 2026-02-17 23:44:28,187	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=19306) 2026-02-17 23:44:28,187	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=19306) 2026-02-17 23:44:28,187	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=19306) 2026-02-17 23:44:28,187	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-17 23:44:28,909	INFO trainable.py:172 -- Trainable.setup took 10.910 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-17 23:44:28,910	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 3 ===
# (RolloutWorker pid=19924) 2026-02-18 00:30:14,472	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=19924) 2026-02-18 00:30:14,472	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=19924) 2026-02-18 00:30:14,473	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=19924) 2026-02-18 00:30:14,473	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=20282) 2026-02-18 00:30:21,683	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=20282) 2026-02-18 00:30:21,683	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=20282) 2026-02-18 00:30:21,683	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=20282) 2026-02-18 00:30:21,683	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-18 00:30:22,409	INFO trainable.py:172 -- Trainable.setup took 10.872 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-18 00:30:22,410	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 4 ===
# (RolloutWorker pid=20894) 2026-02-18 01:15:45,958	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=20894) 2026-02-18 01:15:45,958	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=20894) 2026-02-18 01:15:45,958	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=20894) 2026-02-18 01:15:45,958	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=21253) 2026-02-18 01:15:53,129	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=21253) 2026-02-18 01:15:53,129	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=21253) 2026-02-18 01:15:53,129	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=21253) 2026-02-18 01:15:53,129	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-02-18 01:15:53,850	INFO trainable.py:172 -- Trainable.setup took 10.856 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-02-18 01:15:53,851	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# ### Load the model to print policy

# %%
MODEL_PATH = "/home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-0/i016_m01/sb3_model.zip"  # <- your file
ENV_ID     = "testSC"
CSV_OUT    = "/home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-0/i016_m01/action_plan.csv"

# 1) Check the env spaces (what you're creating right now)
env = gym.make(ENV_ID, max_steps=100)
print("ENV observation_space:", env.observation_space)
print("ENV action_space     :", env.action_space)

obs, info = env.reset()
print("ENV reset obs shape  :", getattr(obs, "shape", type(obs)))

# 2) Check the model spaces (what it was trained with) WITHOUT attaching an env
model = PPO.load(MODEL_PATH, env=None)
print("MODEL observation_space:", model.observation_space)
print("MODEL action_space     :", model.action_space)
# Out:
# ENV observation_space: Box(0.0, 1.0, (114,), float32)
# ENV action_space     : Box(-1.0, 1.0, (64,), float32)
# ENV reset obs shape  : (114,)
# MODEL observation_space: Box(0.0, 1.0, (114,), float32)
# MODEL action_space     : Box(-1.0, 1.0, (64,), float32)

# %%
run = 9
MODEL_PATH = f"/home/rifnyrachman7/_merlion/training_data/complex_sc_v0/finetuning_sb3-{run}/i009_m01/sb3_model.zip"  # <- your file
ENV_ID     = "testSC"
CSV_OUT    = f"/home/rifnyrachman7/_merlion/visualisation/action_com_merlion-{run}.csv"

env = gym.make(ENV_ID, max_steps=100)
model = PPO.load(MODEL_PATH, env=env)

# Try to obtain human-readable action labels, otherwise use a[i]
action_labels = None
ue = getattr(env, "unwrapped", env)
for attr in ("get_action_names", "action_names", "action_labels"):
    if hasattr(ue, attr):
        names = getattr(ue, attr)
        action_labels = names() if callable(names) else names
        break

obs, info = env.reset(seed=7)
rows = []
t = 0
while True:
    action, _ = model.predict(obs, deterministic=True)
    action = np.array(action).ravel()

    row = {"t": t}
    if action_labels and len(action_labels) == action.size:
        for name, val in zip(action_labels, action):
            row[name] = float(val)
    else:
        for i, val in enumerate(action):
            row[f"a{i}"] = float(val)

    # Optional: capture reward vector if the env provides it
    mo = info.get("mo_reward")
    if mo is not None and len(mo) >= 3:
        row["profit"]    = float(mo[0])
        row["emission"]  = float(mo[1])
        row["inequality"]= float(mo[2])

    rows.append(row)

    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        break
    t += 1

env.close()

df = pd.DataFrame(rows)
df.to_csv(CSV_OUT, index=False)
print(f"Saved action plan to {CSV_OUT}")
# Out:
# Saved action plan to /home/rifnyrachman7/_merlion/visualisation/action_com_merlion-9.csv
