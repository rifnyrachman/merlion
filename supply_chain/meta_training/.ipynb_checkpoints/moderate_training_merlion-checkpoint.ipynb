# %% [markdown]
# ### This is a trial to run the meta-learning agent in the trial environment
# Population weights: Uniform

# %%
import os, sys
os.environ["PYTHONPATH"] = "/home/rifnyrachman7"
sys.path.append("/home/rifnyrachman7/_merlion/")
sys.path.append("/home/rifnyrachman7/_merlion/ds-project-messiah/src")
sys.path.append("/home/rifnyrachman7/")

# %%
from gymnasium.wrappers import TimeLimit
import gymnasium as gym
from pathlib import Path

# Import both modules
from _metamorl.algo_ray.rllib.algorithms.maml.merlion_main_multitasks import MERLION, MERLIONConfig
from _metamorl.algo_ray.rllib.algorithms.maml.callback_save_population import _find_archive , MERLIONWithSaveCallbacks

 #v2.3.1 #use algo from local repo
import ray
from ray import air, tune
from ray.tune.registry import register_env
from gymnasium.wrappers import TimeLimit
from ray.air import Checkpoint
from ray.rllib.algorithms.algorithm import Algorithm

# Import the required modules

from messiah.environment import Environment
from messiah.agents.processing import MaxAvailableProcessingAgent

import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

import tempfile
import pickle
import json


#from utils.plot_utils import PlotUtils

# %%
#import generated environment
from _merlion.random_env import moderate_env_merlion
moderate_sc = moderate_env_merlion.ModerateSC()
#simple_sc.save_filename = "/home/rifnyrachman7/_merlion/random_env/simple_reward.pkl"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def save_full_checkpoints_for_population(algo, out_dir: str):
    archive = _find_archive(algo)
    if archive is None:
        print("[SavePopulation] MERLION archive not found on algorithm; skipping.")
        return

    out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)

    pol = algo.get_policy()
    P = int(getattr(archive, "population_size", len(getattr(archive, "archive", []))))

    for i in range(P):
        item = archive.get_archive_item(i)
        if item is None:
            continue

        theta_i = item["theta"]
        w_i = np.asarray(item["weight"], dtype=np.float32)   # <- correct key

        # save the full RLlib checkpoint for policy i
        pol.set_weights(theta_i)
        ckpt_dir = out / f"checkpoint_policy_{i}"
        ckpt_dir.mkdir(parents=True, exist_ok=True)
        path = algo.save(str(ckpt_dir))
        print(f"[SavePopulation] Saved RLlib checkpoint for i={i} → {path}")

        # save the associated weight next to it
        with open(ckpt_dir / "weight.json", "w") as f:
            json.dump([float(x) for x in w_i.ravel().tolist()], f)

# %%
ray.shutdown()
ray.init()

register_env("moderate_sc", lambda cfg: moderate_env_merlion.make_env(cfg))

rollout_fragment_length = 32 #default 32
# Out:
# 2026-01-28 10:20:10,132	WARNING utils.py:640 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2026-01-28 10:20:10,133	WARNING utils.py:652 -- Ray currently does not support initializing Raywith fractional cpus. Your num_cpus will be truncated from 13.68 to 13.
# 2026-01-28 10:20:10,134	WARNING services.py:1780 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2026-01-28 10:20:10,251	INFO worker.py:1544 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265

# %% [markdown]
# ### Adaptation and Metalearning Phase

# %%
seed_base = 99

config = (
    MERLIONConfig()
    .rollouts(
        num_rollout_workers=4, rollout_fragment_length=rollout_fragment_length
    )
    .framework("torch")
    .environment("moderate_sc", clip_actions=True)
    .training(
        inner_adaptation_steps=4,
        meta_batch_size=4, # follow rollout_workers in MIRACL that represent task batch number
        maml_optimizer_steps=10,
        gamma=0.99,
        lambda_=1.0,
        lr=0.001,
        vf_loss_coeff=0.5,
        inner_lr=0.03,
        use_meta_env=True,
        clip_param=0.3,
        kl_target=0.01,
        kl_coeff=0.001,
        model=dict(fcnet_hiddens=[64, 64]),
        train_batch_size=rollout_fragment_length,
        
        #MERLION specific parameters
        population_size = 21, #default # TO DO: ablation for this
        num_objectives = 3,
    )
    .evaluation(
        evaluation_num_workers=1,
        evaluation_interval=100,
        enable_async_evaluation=True,
    )
    .callbacks(MERLIONWithSaveCallbacks)
)

# %%
local_dir = "/home/rifnyrachman7/_merlion/training_data/moderate_sc"
num_iterations = 22 #default 500

results = {}
runs = 10 #run multiple times for model robustness
for k in range(runs):
    print(f"RUNNING NUMBER-{k}")
    
    tuner = tune.Tuner(
        MERLION,
        param_space=config.to_dict(),
        run_config=air.RunConfig(
            name=f"merlion_moderate_{k}",
            local_dir = local_dir,
            stop={"training_iteration": num_iterations},
            failure_config=air.FailureConfig(fail_fast="raise"),
            log_to_file=True,
            checkpoint_config=air.CheckpointConfig(checkpoint_at_end=True, num_to_keep=1),  # ensure a checkpoint exists
        )
    )
    results[k] = tuner.fit()
    
    # #save the best checkpoint for each run
    best = results[k].get_best_result()
    algo = Algorithm.from_checkpoint(best.checkpoint)
    
    out_dir = os.path.join(local_dir, f"metapolicies-{k}")
    os.makedirs(out_dir, exist_ok=True)
    save_full_checkpoints_for_population(algo, out_dir)
# Out:
# RUNNING NUMBER-0
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2026-01-22 00:04:31</td></tr>
# <tr><td>Running for: </td><td>00:44:34.35        </td></tr>
# <tr><td>Memory:      </td><td>33.8/123.8 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 6.0/13 CPUs, 0/0 GPUs, 0.0/64.46 GiB heap, 0.0/9.31 GiB objects
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>MERLION_moderate_sc_b3133_00000</td><td>RUNNING </td><td>10.131.33.49:33699</td><td style="text-align: right;">    16</td><td style="text-align: right;">         2528.88</td><td style="text-align: right;">737600</td><td style="text-align: right;"> 50.5232</td><td style="text-align: right;">             55.4744</td><td style="text-align: right;">             42.0055</td><td style="text-align: right;">               100</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# /home/rifnyrachman7/.local/lib/python3.10/site-packages/ray/tune/execution/trial_runner.py:402: UserWarning: fail_fast='raise' detected. Be careful when using this mode as resources (such as Ray processes, file descriptors, and temporary files) may not be cleaned up properly. To use a safer mode, use fail_fast=True.
#   warnings.warn(
# (MERLION pid=33699) 2026-01-21 23:20:00,119	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# (MERLION pid=33699) 2026-01-21 23:20:00,119	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# (MERLION pid=33699) 2026-01-21 23:20:00,629	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (MERLION pid=33699) 2026-01-21 23:20:00,629	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (RolloutWorker pid=33790) 2026-01-21 23:20:04,346	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=33790) 2026-01-21 23:20:04,346	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=33790) 2026-01-21 23:20:04,346	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=33790) 2026-01-21 23:20:04,346	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (MERLION pid=33699) 2026-01-21 23:20:05,218	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (MERLION pid=33699) 2026-01-21 23:20:05,218	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (MERLION pid=33699) 2026-01-21 23:20:05,219	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (MERLION pid=33699) 2026-01-21 23:20:05,219	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (MERLION pid=33699) 2026-01-21 23:20:07,775	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# (MERLION pid=33699) 2026-01-21 23:20:07,775	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# (RolloutWorker pid=34161) 2026-01-21 23:20:11,328	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=34161) 2026-01-21 23:20:11,328	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=34161) 2026-01-21 23:20:11,328	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=34161) 2026-01-21 23:20:11,328	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (MERLION pid=33699) 2026-01-21 23:20:12,003	INFO trainable.py:172 -- Trainable.setup took 11.376 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (MERLION pid=33699) 2026-01-21 23:20:12,004	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 0) ===
# (MERLION pid=33699) 00 w=[0.052,0.460,0.489] obj=[   0.23,   0.62,   0.70] sc=    0.640  <- OK
# (MERLION pid=33699) 01 w=[0.180,0.495,0.325] obj=[   0.22,   0.60,   0.72] sc=    0.569  <- OK
# (MERLION pid=33699) 02 w=[0.343,0.085,0.573] obj=[   0.31,   0.58,   0.72] sc=    0.568  <- OK
# (MERLION pid=33699) 03 w=[0.332,0.462,0.206] obj=[   0.08,   0.61,   0.68] sc=    0.451  <- OK
# (MERLION pid=33699) 04 w=[0.386,0.365,0.249] obj=[   0.25,   0.60,   0.72] sc=    0.496  <- OK
# (MERLION pid=33699) 05 w=[0.044,0.632,0.324] obj=[   0.10,   0.62,   0.73] sc=    0.634  <- OK
# (MERLION pid=33699) 06 w=[0.182,0.728,0.090] obj=[   0.36,   0.63,   0.72] sc=    0.586  <- OK
# (MERLION pid=33699) 07 w=[0.745,0.206,0.049] obj=[   0.16,   0.64,   0.75] sc=    0.285  <- OK
# (MERLION pid=33699) 08 w=[0.503,0.122,0.375] obj=[   0.28,   0.63,   0.70] sc=    0.480  <- OK
# (MERLION pid=33699) 09 w=[0.189,0.087,0.724] obj=[   0.23,   0.60,   0.72] sc=    0.616  <- OK
# (MERLION pid=33699) 10 w=[0.623,0.251,0.126] obj=[   0.19,   0.60,   0.70] sc=    0.356  <- OK
# (MERLION pid=33699) 11 w=[0.425,0.405,0.170] obj=[   0.21,   0.60,   0.72] sc=    0.454  <- OK
# (MERLION pid=33699) 12 w=[0.372,0.510,0.119] obj=[   0.24,   0.61,   0.71] sc=    0.484  <- OK
# (MERLION pid=33699) 13 w=[0.020,0.734,0.246] obj=[   0.17,   0.63,   0.70] sc=    0.640  <- OK
# (MERLION pid=33699) 14 w=[0.838,0.151,0.011] obj=[   0.26,   0.61,   0.69] sc=    0.315  <- OK
# (MERLION pid=33699) 15 w=[0.222,0.343,0.435] obj=[   0.05,   0.60,   0.71] sc=    0.525  <- OK
# (MERLION pid=33699) 16 w=[0.153,0.222,0.626] obj=[   0.11,   0.58,   0.71] sc=    0.589  <- OK
# (MERLION pid=33699) 17 w=[0.277,0.480,0.242] obj=[   0.36,   0.60,   0.73] sc=    0.562  <- OK
# (MERLION pid=33699) 18 w=[0.055,0.171,0.774] obj=[   0.16,   0.61,   0.70] sc=    0.656  <- OK
# (MERLION pid=33699) 19 w=[0.024,0.168,0.807] obj=[   0.28,   0.62,   0.71] sc=    0.683  <- OK
# (MERLION pid=33699) 20 w=[0.185,0.314,0.502] obj=[   0.23,   0.61,   0.70] sc=    0.582  <- OK
# (MERLION pid=33699) ================================================================
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                     </th><th style="text-align: right;">  adaptation_delta</th><th style="text-align: right;">  agent_timesteps_total</th><th>connector_metrics                                                                                                                                              </th><th>custom_metrics  </th><th>date               </th><th>done  </th><th style="text-align: right;">  episode_len_mean</th><th>episode_media  </th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_max_adapt_1</th><th style="text-align: right;">  episode_reward_max_adapt_2</th><th style="text-align: right;">  episode_reward_max_adapt_3</th><th style="text-align: right;">  episode_reward_max_adapt_4</th><th style="text-align: right;">  episode_reward_mean</th><th style="text-align: right;">  episode_reward_mean_adapt_1</th><th style="text-align: right;">  episode_reward_mean_adapt_2</th><th style="text-align: right;">  episode_reward_mean_adapt_3</th><th style="text-align: right;">  episode_reward_mean_adapt_4</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_reward_min_adapt_1</th><th style="text-align: right;">  episode_reward_min_adapt_2</th><th style="text-align: right;">  episode_reward_min_adapt_3</th><th style="text-align: right;">  episode_reward_min_adapt_4</th><th style="text-align: right;">  episodes_this_iter</th><th style="text-align: right;">  episodes_total</th><th>experiment_id                   </th><th>hostname                                        </th><th>info                                                                                                                                                                                                                                                                                                                                                                                     </th><th style="text-align: right;">  iterations_since_restore</th><th>node_ip     </th><th style="text-align: right;">  num_faulty_episodes</th><th style="text-align: right;">  num_healthy_workers</th><th>perf                                                                           </th><th style="text-align: right;">  pid</th><th>policy_reward_max  </th><th>policy_reward_mean  </th><th>policy_reward_min  </th><th>sampler_perf                                                                                                                                                                                                    </th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th>timers  </th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th style="text-align: right;">  timesteps_this_iter</th><th style="text-align: right;">  timesteps_total</th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>MERLION_moderate_sc_b3133_00000</td><td style="text-align: right;">          0.417812</td><td style="text-align: right;">                      0</td><td>{&#x27;ObsPreprocessorConnector_ms&#x27;: 0.004298562635910484, &#x27;StateBufferConnector_ms&#x27;: 0.0032357347795482125, &#x27;ViewRequirementAgentConnector_ms&#x27;: 0.0790496532068231}</td><td>{}              </td><td>2026-01-22_00-02-21</td><td>False </td><td style="text-align: right;">               100</td><td>{}             </td><td style="text-align: right;">             55.4744</td><td style="text-align: right;">                     59.4041</td><td style="text-align: right;">                     57.9112</td><td style="text-align: right;">                      56.901</td><td style="text-align: right;">                     52.8523</td><td style="text-align: right;">              50.5232</td><td style="text-align: right;">                      47.4746</td><td style="text-align: right;">                      51.4409</td><td style="text-align: right;">                      48.7651</td><td style="text-align: right;">                       50.941</td><td style="text-align: right;">             42.0055</td><td style="text-align: right;">                      36.474</td><td style="text-align: right;">                     46.7133</td><td style="text-align: right;">                     43.7874</td><td style="text-align: right;">                     46.3781</td><td style="text-align: right;">                 441</td><td style="text-align: right;">            7056</td><td>80186df90bdd4f7e8571688ee284db1b</td><td>workspace-580f8f1b-0605-48d2-b4f5-8608dc1d24e9-0</td><td>{&#x27;learner&#x27;: {&#x27;default_policy&#x27;: {&#x27;learner_stats&#x27;: {&#x27;allreduce_latency&#x27;: 0.0, &#x27;grad_gnorm&#x27;: 1.0, &#x27;worker_loss&#x27;: 43.91499328613281}, &#x27;model&#x27;: {}, &#x27;custom_metrics&#x27;: {}, &#x27;num_agent_steps_trained&#x27;: 2000, &#x27;num_grad_updates_lifetime&#x27;: 864, &#x27;diff_num_grad_updates_vs_sampler_policy&#x27;: 9.0}}, &#x27;num_steps_sampled&#x27;: 691500, &#x27;num_steps_trained_this_iter&#x27;: 46100, &#x27;num_steps_trained&#x27;: 691500}</td><td style="text-align: right;">                        16</td><td>10.131.33.49</td><td style="text-align: right;">                    0</td><td style="text-align: right;">                    5</td><td>{&#x27;cpu_util_percent&#x27;: 15.64304932735426, &#x27;ram_util_percent&#x27;: 26.494618834080715}</td><td style="text-align: right;">33699</td><td>{}                 </td><td>{}                  </td><td>{}                 </td><td>{&#x27;mean_raw_obs_processing_ms&#x27;: 0.5635955228242222, &#x27;mean_inference_ms&#x27;: 0.6940094888668241, &#x27;mean_action_processing_ms&#x27;: 0.13136642395582934, &#x27;mean_env_wait_ms&#x27;: 1.8608043480442586, &#x27;mean_env_render_ms&#x27;: 0.0}</td><td style="text-align: right;">             2528.88</td><td style="text-align: right;">            156.76</td><td style="text-align: right;">       2528.88</td><td>{}      </td><td style="text-align: right;"> 1769040141</td><td style="text-align: right;">                   737600</td><td style="text-align: right;">                46100</td><td style="text-align: right;">           737600</td><td style="text-align: right;">                  16</td><td>b3133_00000</td><td style="text-align: right;">      11.3792</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=46100
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 1) ===
# (MERLION pid=33699) 00 w=[0.838,0.151,0.011] obj=[   0.33,   0.59,   0.71] sc=    0.378  <- OK
# (MERLION pid=33699) 01 w=[0.171,0.555,0.274] obj=[   0.27,   0.59,   0.70] sc=    0.569  <- OK
# (MERLION pid=33699) 02 w=[0.919,0.081,0.000] obj=[   0.33,   0.60,   0.72] sc=    0.348  <- OK
# (MERLION pid=33699) 03 w=[0.440,0.192,0.368] obj=[   0.21,   0.61,   0.71] sc=    0.470  <- OK
# (MERLION pid=33699) 04 w=[0.369,0.292,0.339] obj=[   0.27,   0.63,   0.73] sc=    0.531  <- OK
# (MERLION pid=33699) 05 w=[0.420,0.189,0.391] obj=[   0.16,   0.62,   0.70] sc=    0.459  <- OK
# (MERLION pid=33699) 06 w=[0.604,0.224,0.172] obj=[   0.24,   0.61,   0.71] sc=    0.406  <- OK
# (MERLION pid=33699) 07 w=[0.372,0.394,0.233] obj=[   0.11,   0.61,   0.71] sc=    0.447  <- OK
# (MERLION pid=33699) 08 w=[0.153,0.000,0.847] obj=[   0.38,   0.58,   0.70] sc=    0.648  <- OK
# (MERLION pid=33699) 09 w=[0.662,0.285,0.053] obj=[   0.08,   0.60,   0.71] sc=    0.261  <- OK
# (MERLION pid=33699) 10 w=[0.233,0.464,0.303] obj=[   0.09,   0.62,   0.72] sc=    0.524  <- OK
# (MERLION pid=33699) 11 w=[0.753,0.212,0.036] obj=[   0.17,   0.55,   0.72] sc=    0.268  <- OK
# (MERLION pid=33699) 12 w=[0.194,0.468,0.337] obj=[   0.16,   0.61,   0.70] sc=    0.555  <- OK
# (MERLION pid=33699) 13 w=[0.117,0.166,0.717] obj=[   0.18,   0.60,   0.72] sc=    0.635  <- OK
# (MERLION pid=33699) 14 w=[0.234,0.164,0.602] obj=[   0.36,   0.60,   0.72] sc=    0.619  <- OK
# (MERLION pid=33699) 15 w=[0.410,0.319,0.271] obj=[   0.25,   0.57,   0.71] sc=    0.479  <- OK
# (MERLION pid=33699) 16 w=[0.071,0.214,0.715] obj=[   0.21,   0.62,   0.75] sc=    0.681  <- OK
# (MERLION pid=33699) 17 w=[0.143,0.285,0.573] obj=[   0.29,   0.64,   0.69] sc=    0.618  <- OK
# (MERLION pid=33699) 18 w=[0.826,0.137,0.037] obj=[   0.26,   0.62,   0.72] sc=    0.327  <- OK
# (MERLION pid=33699) 19 w=[0.007,0.812,0.181] obj=[   0.22,   0.60,   0.71] sc=    0.615  <- OK
# (MERLION pid=33699) 20 w=[0.588,0.249,0.163] obj=[   0.21,   0.62,   0.73] sc=    0.399  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=92200
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 2) ===
# (MERLION pid=33699) 00 w=[0.007,0.812,0.181] obj=[   0.30,   0.61,   0.73] sc=    0.627  <- OK
# (MERLION pid=33699) 01 w=[0.324,0.144,0.532] obj=[   0.32,   0.59,   0.72] sc=    0.568  <- OK
# (MERLION pid=33699) 02 w=[0.766,0.204,0.030] obj=[   0.25,   0.61,   0.73] sc=    0.341  <- OK
# (MERLION pid=33699) 03 w=[0.635,0.294,0.071] obj=[   0.27,   0.61,   0.71] sc=    0.398  <- OK
# (MERLION pid=33699) 04 w=[0.303,0.084,0.613] obj=[   0.17,   0.61,   0.68] sc=    0.517  <- OK
# (MERLION pid=33699) 05 w=[0.903,0.034,0.063] obj=[   0.33,   0.60,   0.72] sc=    0.359  <- OK
# (MERLION pid=33699) 06 w=[0.348,0.020,0.632] obj=[   0.16,   0.59,   0.71] sc=    0.515  <- OK
# (MERLION pid=33699) 07 w=[0.664,0.180,0.155] obj=[   0.35,   0.59,   0.71] sc=    0.452  <- OK
# (MERLION pid=33699) 08 w=[0.085,0.286,0.629] obj=[   0.26,   0.63,   0.72] sc=    0.654  <- OK
# (MERLION pid=33699) 09 w=[0.530,0.040,0.430] obj=[   0.24,   0.61,   0.73] sc=    0.463  <- OK
# (MERLION pid=33699) 10 w=[0.569,0.118,0.313] obj=[   0.26,   0.60,   0.69] sc=    0.435  <- OK
# (MERLION pid=33699) 11 w=[0.223,0.225,0.552] obj=[   0.07,   0.62,   0.70] sc=    0.544  <- OK
# (MERLION pid=33699) 12 w=[0.683,0.255,0.062] obj=[   0.29,   0.60,   0.69] sc=    0.394  <- OK
# (MERLION pid=33699) 13 w=[0.307,0.168,0.525] obj=[   0.26,   0.59,   0.70] sc=    0.548  <- OK
# (MERLION pid=33699) 14 w=[0.143,0.073,0.784] obj=[   0.18,   0.59,   0.72] sc=    0.631  <- OK
# (MERLION pid=33699) 15 w=[0.066,0.828,0.105] obj=[   0.21,   0.60,   0.72] sc=    0.586  <- OK
# (MERLION pid=33699) 16 w=[0.667,0.215,0.117] obj=[   0.25,   0.58,   0.70] sc=    0.372  <- OK
# (MERLION pid=33699) 17 w=[0.741,0.178,0.081] obj=[   0.30,   0.61,   0.72] sc=    0.386  <- OK
# (MERLION pid=33699) 18 w=[0.381,0.050,0.569] obj=[   0.25,   0.61,   0.74] sc=    0.548  <- OK
# (MERLION pid=33699) 19 w=[0.242,0.187,0.571] obj=[   0.24,   0.59,   0.71] sc=    0.576  <- OK
# (MERLION pid=33699) 20 w=[0.326,0.380,0.294] obj=[   0.31,   0.61,   0.72] sc=    0.547  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=138300
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 3) ===
# (MERLION pid=33699) 00 w=[0.007,0.812,0.181] obj=[   0.08,   0.60,   0.71] sc=    0.612  <- OK
# (MERLION pid=33699) 01 w=[0.357,0.161,0.483] obj=[   0.18,   0.61,   0.74] sc=    0.516  <- OK
# (MERLION pid=33699) 02 w=[0.583,0.258,0.158] obj=[   0.24,   0.57,   0.70] sc=    0.397  <- OK
# (MERLION pid=33699) 03 w=[0.173,0.157,0.671] obj=[   0.31,   0.61,   0.72] sc=    0.631  <- OK
# (MERLION pid=33699) 04 w=[0.238,0.537,0.225] obj=[   0.41,   0.59,   0.72] sc=    0.574  <- OK
# (MERLION pid=33699) 05 w=[0.053,0.125,0.823] obj=[   0.29,   0.59,   0.71] sc=    0.674  <- OK
# (MERLION pid=33699) 06 w=[0.173,0.668,0.159] obj=[   0.38,   0.57,   0.71] sc=    0.557  <- OK
# (MERLION pid=33699) 07 w=[0.461,0.454,0.085] obj=[   0.26,   0.60,   0.70] sc=    0.454  <- OK
# (MERLION pid=33699) 08 w=[0.384,0.527,0.089] obj=[   0.20,   0.61,   0.73] sc=    0.462  <- OK
# (MERLION pid=33699) 09 w=[0.787,0.213,0.000] obj=[   0.23,   0.62,   0.70] sc=    0.315  <- OK
# (MERLION pid=33699) 10 w=[0.419,0.170,0.411] obj=[   0.26,   0.59,   0.73] sc=    0.507  <- OK
# (MERLION pid=33699) 11 w=[0.098,0.729,0.173] obj=[   0.32,   0.61,   0.70] sc=    0.596  <- OK
# (MERLION pid=33699) 12 w=[0.230,0.598,0.172] obj=[   0.15,   0.61,   0.69] sc=    0.519  <- OK
# (MERLION pid=33699) 13 w=[0.808,0.064,0.129] obj=[   0.10,   0.59,   0.70] sc=    0.206  <- OK
# (MERLION pid=33699) 14 w=[0.423,0.412,0.165] obj=[   0.29,   0.59,   0.72] sc=    0.485  <- OK
# (MERLION pid=33699) 15 w=[0.409,0.193,0.398] obj=[   0.10,   0.62,   0.72] sc=    0.448  <- OK
# (MERLION pid=33699) 16 w=[0.381,0.061,0.558] obj=[   0.31,   0.59,   0.71] sc=    0.554  <- OK
# (MERLION pid=33699) 17 w=[0.020,0.800,0.180] obj=[   0.30,   0.59,   0.73] sc=    0.613  <- OK
# (MERLION pid=33699) 18 w=[0.525,0.261,0.214] obj=[   0.28,   0.60,   0.69] sc=    0.453  <- OK
# (MERLION pid=33699) 19 w=[0.250,0.375,0.375] obj=[   0.31,   0.58,   0.72] sc=    0.567  <- OK
# (MERLION pid=33699) 20 w=[0.569,0.325,0.107] obj=[   0.29,   0.59,   0.71] sc=    0.433  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=184400
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 4) ===
# (MERLION pid=33699) 00 w=[0.053,0.125,0.823] obj=[   0.26,   0.61,   0.72] sc=    0.683  <- OK
# (MERLION pid=33699) 01 w=[0.114,0.613,0.273] obj=[   0.05,   0.60,   0.72] sc=    0.573  <- OK
# (MERLION pid=33699) 02 w=[0.745,0.195,0.060] obj=[   0.23,   0.59,   0.70] sc=    0.330  <- OK
# (MERLION pid=33699) 03 w=[0.421,0.169,0.411] obj=[   0.39,   0.60,   0.74] sc=    0.570  <- OK
# (MERLION pid=33699) 04 w=[0.224,0.387,0.388] obj=[   0.23,   0.60,   0.73] sc=    0.566  <- OK
# (MERLION pid=33699) 05 w=[0.108,0.248,0.644] obj=[   0.36,   0.60,   0.69] sc=    0.632  <- OK
# (MERLION pid=33699) 06 w=[0.427,0.180,0.393] obj=[   0.24,   0.60,   0.72] sc=    0.493  <- OK
# (MERLION pid=33699) 07 w=[0.606,0.196,0.198] obj=[   0.25,   0.60,   0.71] sc=    0.411  <- OK
# (MERLION pid=33699) 08 w=[0.706,0.125,0.170] obj=[   0.22,   0.62,   0.73] sc=    0.353  <- OK
# (MERLION pid=33699) 09 w=[0.400,0.225,0.375] obj=[   0.22,   0.59,   0.73] sc=    0.492  <- OK
# (MERLION pid=33699) 10 w=[0.188,0.448,0.364] obj=[   0.31,   0.59,   0.70] sc=    0.574  <- OK
# (MERLION pid=33699) 11 w=[0.411,0.434,0.154] obj=[   0.23,   0.58,   0.72] sc=    0.455  <- OK
# (MERLION pid=33699) 12 w=[0.404,0.178,0.418] obj=[   0.25,   0.63,   0.72] sc=    0.514  <- OK
# (MERLION pid=33699) 13 w=[0.704,0.160,0.135] obj=[   0.34,   0.61,   0.71] sc=    0.437  <- OK
# (MERLION pid=33699) 14 w=[0.280,0.571,0.149] obj=[   0.25,   0.59,   0.71] sc=    0.514  <- OK
# (MERLION pid=33699) 15 w=[0.219,0.614,0.167] obj=[   0.24,   0.60,   0.72] sc=    0.543  <- OK
# (MERLION pid=33699) 16 w=[0.325,0.344,0.331] obj=[   0.28,   0.60,   0.71] sc=    0.532  <- OK
# (MERLION pid=33699) 17 w=[0.659,0.202,0.138] obj=[   0.24,   0.60,   0.70] sc=    0.374  <- OK
# (MERLION pid=33699) 18 w=[0.506,0.345,0.148] obj=[   0.22,   0.59,   0.72] sc=    0.421  <- OK
# (MERLION pid=33699) 19 w=[0.341,0.197,0.462] obj=[   0.41,   0.56,   0.74] sc=    0.590  <- OK
# (MERLION pid=33699) 20 w=[0.704,0.205,0.091] obj=[   0.22,   0.61,   0.70] sc=    0.341  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=230500
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 5) ===
# (MERLION pid=33699) 00 w=[0.053,0.125,0.823] obj=[   0.24,   0.59,   0.74] sc=    0.693  <- OK
# (MERLION pid=33699) 01 w=[0.750,0.250,0.000] obj=[   0.23,   0.62,   0.72] sc=    0.331  <- OK
# (MERLION pid=33699) 02 w=[0.327,0.161,0.512] obj=[   0.30,   0.61,   0.71] sc=    0.559  <- OK
# (MERLION pid=33699) 03 w=[0.115,0.216,0.669] obj=[   0.22,   0.60,   0.71] sc=    0.628  <- OK
# (MERLION pid=33699) 04 w=[0.303,0.390,0.307] obj=[   0.24,   0.61,   0.71] sc=    0.531  <- OK
# (MERLION pid=33699) 05 w=[0.478,0.177,0.345] obj=[   0.07,   0.60,   0.71] sc=    0.389  <- OK
# (MERLION pid=33699) 06 w=[0.656,0.235,0.109] obj=[   0.21,   0.60,   0.70] sc=    0.357  <- OK
# (MERLION pid=33699) 07 w=[0.420,0.410,0.170] obj=[   0.07,   0.59,   0.70] sc=    0.389  <- OK
# (MERLION pid=33699) 08 w=[0.418,0.162,0.421] obj=[   0.20,   0.59,   0.72] sc=    0.482  <- OK
# (MERLION pid=33699) 09 w=[0.501,0.215,0.284] obj=[   0.20,   0.58,   0.71] sc=    0.428  <- OK
# (MERLION pid=33699) 10 w=[0.121,0.259,0.620] obj=[   0.32,   0.60,   0.70] sc=    0.630  <- OK
# (MERLION pid=33699) 11 w=[0.113,0.242,0.645] obj=[   0.24,   0.62,   0.72] sc=    0.643  <- OK
# (MERLION pid=33699) 12 w=[0.281,0.233,0.486] obj=[   0.45,   0.58,   0.71] sc=    0.610  <- OK
# (MERLION pid=33699) 13 w=[0.535,0.184,0.280] obj=[   0.30,   0.58,   0.72] sc=    0.469  <- OK
# (MERLION pid=33699) 14 w=[0.617,0.182,0.201] obj=[   0.17,   0.59,   0.69] sc=    0.352  <- OK
# (MERLION pid=33699) 15 w=[0.400,0.223,0.376] obj=[   0.33,   0.60,   0.71] sc=    0.533  <- OK
# (MERLION pid=33699) 16 w=[0.529,0.173,0.298] obj=[   0.18,   0.63,   0.70] sc=    0.415  <- OK
# (MERLION pid=33699) 17 w=[0.416,0.104,0.480] obj=[   0.29,   0.59,   0.71] sc=    0.524  <- OK
# (MERLION pid=33699) 18 w=[0.378,0.165,0.458] obj=[   0.33,   0.60,   0.70] sc=    0.542  <- OK
# (MERLION pid=33699) 19 w=[0.079,0.284,0.637] obj=[   0.23,   0.60,   0.74] sc=    0.658  <- OK
# (MERLION pid=33699) 20 w=[0.680,0.238,0.082] obj=[   0.27,   0.62,   0.72] sc=    0.388  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=276600
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 6) ===
# (MERLION pid=33699) 00 w=[0.053,0.125,0.823] obj=[   0.29,   0.60,   0.72] sc=    0.683  <- OK
# (MERLION pid=33699) 01 w=[0.510,0.208,0.282] obj=[   0.22,   0.60,   0.69] sc=    0.434  <- OK
# (MERLION pid=33699) 02 w=[0.702,0.166,0.132] obj=[   0.22,   0.62,   0.71] sc=    0.350  <- OK
# (MERLION pid=33699) 03 w=[0.329,0.175,0.495] obj=[   0.30,   0.61,   0.69] sc=    0.545  <- OK
# (MERLION pid=33699) 04 w=[0.472,0.246,0.282] obj=[   0.24,   0.60,   0.73] sc=    0.467  <- OK
# (MERLION pid=33699) 05 w=[0.390,0.498,0.112] obj=[   0.24,   0.61,   0.72] sc=    0.475  <- OK
# (MERLION pid=33699) 06 w=[0.258,0.162,0.580] obj=[   0.24,   0.61,   0.70] sc=    0.565  <- OK
# (MERLION pid=33699) 07 w=[0.157,0.231,0.612] obj=[   0.15,   0.59,   0.71] sc=    0.597  <- OK
# (MERLION pid=33699) 08 w=[0.498,0.226,0.276] obj=[   0.34,   0.62,   0.72] sc=    0.507  <- OK
# (MERLION pid=33699) 09 w=[0.647,0.205,0.148] obj=[   0.21,   0.60,   0.70] sc=    0.363  <- OK
# (MERLION pid=33699) 10 w=[0.138,0.315,0.547] obj=[   0.30,   0.59,   0.75] sc=    0.634  <- OK
# (MERLION pid=33699) 11 w=[0.491,0.204,0.305] obj=[   0.35,   0.58,   0.74] sc=    0.518  <- OK
# (MERLION pid=33699) 12 w=[0.105,0.165,0.729] obj=[   0.21,   0.62,   0.72] sc=    0.649  <- OK
# (MERLION pid=33699) 13 w=[0.646,0.204,0.149] obj=[   0.27,   0.59,   0.70] sc=    0.398  <- OK
# (MERLION pid=33699) 14 w=[0.410,0.165,0.425] obj=[   0.20,   0.58,   0.71] sc=    0.481  <- OK
# (MERLION pid=33699) 15 w=[0.130,0.206,0.664] obj=[   0.23,   0.61,   0.72] sc=    0.635  <- OK
# (MERLION pid=33699) 16 w=[0.242,0.144,0.614] obj=[   0.22,   0.62,   0.70] sc=    0.572  <- OK
# (MERLION pid=33699) 17 w=[0.501,0.253,0.246] obj=[   0.30,   0.61,   0.73] sc=    0.482  <- OK
# (MERLION pid=33699) 18 w=[0.482,0.020,0.498] obj=[   0.10,   0.60,   0.74] sc=    0.428  <- OK
# (MERLION pid=33699) 19 w=[0.061,0.320,0.619] obj=[   0.27,   0.61,   0.69] sc=    0.638  <- OK
# (MERLION pid=33699) 20 w=[0.756,0.182,0.061] obj=[   0.21,   0.60,   0.72] sc=    0.311  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=322700
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 7) ===
# (MERLION pid=33699) 00 w=[0.053,0.125,0.823] obj=[   0.16,   0.59,   0.72] sc=    0.672  <- OK
# (MERLION pid=33699) 01 w=[0.065,0.355,0.580] obj=[   0.36,   0.58,   0.71] sc=    0.645  <- OK
# (MERLION pid=33699) 02 w=[0.068,0.164,0.769] obj=[   0.30,   0.62,   0.72] sc=    0.674  <- OK
# (MERLION pid=33699) 03 w=[0.108,0.186,0.706] obj=[   0.23,   0.62,   0.70] sc=    0.637  <- OK
# (MERLION pid=33699) 04 w=[0.313,0.154,0.532] obj=[   0.20,   0.62,   0.72] sc=    0.539  <- OK
# (MERLION pid=33699) 05 w=[0.189,0.135,0.677] obj=[   0.27,   0.58,   0.71] sc=    0.608  <- OK
# (MERLION pid=33699) 06 w=[0.385,0.262,0.353] obj=[   0.13,   0.60,   0.73] sc=    0.469  <- OK
# (MERLION pid=33699) 07 w=[0.700,0.181,0.118] obj=[   0.16,   0.60,   0.73] sc=    0.304  <- OK
# (MERLION pid=33699) 08 w=[0.761,0.167,0.072] obj=[   0.16,   0.60,   0.72] sc=    0.275  <- OK
# (MERLION pid=33699) 09 w=[0.593,0.178,0.229] obj=[   0.30,   0.57,   0.73] sc=    0.446  <- OK
# (MERLION pid=33699) 10 w=[0.299,0.397,0.304] obj=[   0.37,   0.59,   0.73] sc=    0.569  <- OK
# (MERLION pid=33699) 11 w=[0.449,0.497,0.053] obj=[   0.34,   0.60,   0.72] sc=    0.489  <- OK
# (MERLION pid=33699) 12 w=[0.446,0.481,0.073] obj=[   0.37,   0.62,   0.70] sc=    0.511  <- OK
# (MERLION pid=33699) 13 w=[0.557,0.166,0.277] obj=[   0.28,   0.61,   0.70] sc=    0.449  <- OK
# (MERLION pid=33699) 14 w=[0.363,0.190,0.447] obj=[   0.24,   0.60,   0.74] sc=    0.531  <- OK
# (MERLION pid=33699) 15 w=[0.029,0.299,0.673] obj=[   0.30,   0.61,   0.72] sc=    0.674  <- OK
# (MERLION pid=33699) 16 w=[0.650,0.205,0.145] obj=[   0.25,   0.58,   0.68] sc=    0.383  <- OK
# (MERLION pid=33699) 17 w=[0.232,0.143,0.625] obj=[   0.22,   0.60,   0.73] sc=    0.592  <- OK
# (MERLION pid=33699) 18 w=[0.171,0.138,0.691] obj=[   0.20,   0.60,   0.72] sc=    0.618  <- OK
# (MERLION pid=33699) 19 w=[0.649,0.206,0.145] obj=[   0.23,   0.60,   0.72] sc=    0.378  <- OK
# (MERLION pid=33699) 20 w=[0.039,0.352,0.609] obj=[   0.20,   0.60,   0.69] sc=    0.641  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=368800
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 8) ===
# (MERLION pid=33699) 00 w=[0.761,0.167,0.072] obj=[   0.22,   0.60,   0.71] sc=    0.321  <- OK
# (MERLION pid=33699) 01 w=[0.227,0.142,0.631] obj=[   0.27,   0.58,   0.73] sc=    0.606  <- OK
# (MERLION pid=33699) 02 w=[0.482,0.167,0.350] obj=[   0.28,   0.63,   0.71] sc=    0.488  <- OK
# (MERLION pid=33699) 03 w=[0.365,0.408,0.227] obj=[   0.32,   0.62,   0.74] sc=    0.540  <- OK
# (MERLION pid=33699) 04 w=[0.142,0.223,0.635] obj=[   0.24,   0.60,   0.72] sc=    0.623  <- OK
# (MERLION pid=33699) 05 w=[0.000,0.342,0.658] obj=[   0.13,   0.58,   0.70] sc=    0.659  <- OK
# (MERLION pid=33699) 06 w=[0.657,0.107,0.237] obj=[   0.21,   0.60,   0.72] sc=    0.371  <- OK
# (MERLION pid=33699) 07 w=[0.446,0.224,0.330] obj=[   0.41,   0.59,   0.71] sc=    0.549  <- OK
# (MERLION pid=33699) 08 w=[0.415,0.472,0.112] obj=[   0.17,   0.61,   0.73] sc=    0.441  <- OK
# (MERLION pid=33699) 09 w=[0.374,0.416,0.209] obj=[   0.18,   0.60,   0.71] sc=    0.466  <- OK
# (MERLION pid=33699) 10 w=[0.680,0.118,0.202] obj=[   0.19,   0.61,   0.68] sc=    0.337  <- OK
# (MERLION pid=33699) 11 w=[0.566,0.156,0.278] obj=[   0.29,   0.61,   0.75] sc=    0.467  <- OK
# (MERLION pid=33699) 12 w=[0.293,0.287,0.420] obj=[   0.33,   0.56,   0.72] sc=    0.560  <- OK
# (MERLION pid=33699) 13 w=[0.141,0.222,0.637] obj=[   0.35,   0.62,   0.74] sc=    0.655  <- OK
# (MERLION pid=33699) 14 w=[0.489,0.160,0.351] obj=[   0.27,   0.59,   0.71] sc=    0.477  <- OK
# (MERLION pid=33699) 15 w=[0.012,0.205,0.783] obj=[   0.30,   0.59,   0.73] sc=    0.696  <- OK
# (MERLION pid=33699) 16 w=[0.237,0.140,0.623] obj=[   0.24,   0.59,   0.71] sc=    0.580  <- OK
# (MERLION pid=33699) 17 w=[0.130,0.210,0.660] obj=[   0.32,   0.60,   0.72] sc=    0.640  <- OK
# (MERLION pid=33699) 18 w=[0.180,0.142,0.678] obj=[   0.25,   0.60,   0.70] sc=    0.607  <- OK
# (MERLION pid=33699) 19 w=[0.498,0.502,0.000] obj=[   0.14,   0.59,   0.71] sc=    0.367  <- OK
# (MERLION pid=33699) 20 w=[0.140,0.130,0.730] obj=[   0.20,   0.62,   0.70] sc=    0.617  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=414900
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 9) ===
# (MERLION pid=33699) 00 w=[0.761,0.167,0.072] obj=[   0.39,   0.61,   0.71] sc=    0.447  <- OK
# (MERLION pid=33699) 01 w=[0.367,0.374,0.259] obj=[   0.22,   0.58,   0.73] sc=    0.486  <- OK
# (MERLION pid=33699) 02 w=[0.389,0.481,0.131] obj=[   0.36,   0.61,   0.73] sc=    0.528  <- OK
# (MERLION pid=33699) 03 w=[0.134,0.194,0.672] obj=[   0.30,   0.64,   0.73] sc=    0.653  <- OK
# (MERLION pid=33699) 04 w=[0.677,0.189,0.134] obj=[   0.38,   0.59,   0.73] sc=    0.471  <- OK
# (MERLION pid=33699) 05 w=[0.471,0.420,0.109] obj=[   0.30,   0.57,   0.72] sc=    0.459  <- OK
# (MERLION pid=33699) 06 w=[0.587,0.130,0.283] obj=[   0.14,   0.61,   0.73] sc=    0.366  <- OK
# (MERLION pid=33699) 07 w=[0.239,0.288,0.474] obj=[   0.24,   0.58,   0.73] sc=    0.572  <- OK
# (MERLION pid=33699) 08 w=[0.201,0.313,0.486] obj=[   0.42,   0.59,   0.73] sc=    0.624  <- OK
# (MERLION pid=33699) 09 w=[0.577,0.210,0.213] obj=[   0.28,   0.59,   0.68] sc=    0.429  <- OK
# (MERLION pid=33699) 10 w=[0.158,0.302,0.540] obj=[   0.32,   0.60,   0.70] sc=    0.612  <- OK
# (MERLION pid=33699) 11 w=[0.332,0.324,0.344] obj=[   0.25,   0.59,   0.71] sc=    0.520  <- OK
# (MERLION pid=33699) 12 w=[0.443,0.469,0.088] obj=[   0.36,   0.61,   0.70] sc=    0.507  <- OK
# (MERLION pid=33699) 13 w=[0.346,0.205,0.450] obj=[   0.39,   0.59,   0.71] sc=    0.574  <- OK
# (MERLION pid=33699) 14 w=[0.158,0.302,0.540] obj=[   0.20,   0.61,   0.73] sc=    0.612  <- OK
# (MERLION pid=33699) 15 w=[0.490,0.181,0.329] obj=[   0.30,   0.59,   0.71] sc=    0.488  <- OK
# (MERLION pid=33699) 16 w=[0.169,0.296,0.535] obj=[   0.27,   0.61,   0.73] sc=    0.617  <- OK
# (MERLION pid=33699) 17 w=[0.303,0.178,0.519] obj=[   0.25,   0.61,   0.72] sc=    0.555  <- OK
# (MERLION pid=33699) 18 w=[0.405,0.154,0.441] obj=[   0.21,   0.59,   0.71] sc=    0.487  <- OK
# (MERLION pid=33699) 19 w=[0.364,0.174,0.462] obj=[   0.13,   0.60,   0.71] sc=    0.482  <- OK
# (MERLION pid=33699) 20 w=[0.424,0.245,0.331] obj=[   0.32,   0.60,   0.72] sc=    0.520  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=461000
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 10) ===
# (MERLION pid=33699) 00 w=[0.761,0.167,0.072] obj=[   0.34,   0.59,   0.72] sc=    0.407  <- OK
# (MERLION pid=33699) 01 w=[0.752,0.204,0.044] obj=[   0.24,   0.61,   0.70] sc=    0.335  <- OK
# (MERLION pid=33699) 02 w=[0.538,0.158,0.303] obj=[   0.27,   0.62,   0.73] sc=    0.465  <- OK
# (MERLION pid=33699) 03 w=[0.672,0.171,0.157] obj=[   0.42,   0.59,   0.71] sc=    0.492  <- OK
# (MERLION pid=33699) 04 w=[0.560,0.340,0.100] obj=[   0.20,   0.61,   0.73] sc=    0.392  <- OK
# (MERLION pid=33699) 05 w=[0.275,0.353,0.372] obj=[   0.23,   0.61,   0.73] sc=    0.553  <- OK
# (MERLION pid=33699) 06 w=[0.373,0.436,0.191] obj=[   0.20,   0.60,   0.73] sc=    0.477  <- OK
# (MERLION pid=33699) 07 w=[0.670,0.171,0.159] obj=[   0.44,   0.60,   0.71] sc=    0.508  <- OK
# (MERLION pid=33699) 08 w=[0.248,0.189,0.563] obj=[   0.15,   0.60,   0.70] sc=    0.547  <- OK
# (MERLION pid=33699) 09 w=[0.572,0.183,0.245] obj=[   0.25,   0.62,   0.73] sc=    0.434  <- OK
# (MERLION pid=33699) 10 w=[0.228,0.197,0.575] obj=[   0.29,   0.59,   0.72] sc=    0.597  <- OK
# (MERLION pid=33699) 11 w=[0.684,0.186,0.130] obj=[   0.25,   0.59,   0.74] sc=    0.375  <- OK
# (MERLION pid=33699) 12 w=[0.386,0.183,0.431] obj=[   0.24,   0.61,   0.69] sc=    0.503  <- OK
# (MERLION pid=33699) 13 w=[0.370,0.340,0.290] obj=[   0.24,   0.59,   0.70] sc=    0.493  <- OK
# (MERLION pid=33699) 14 w=[0.306,0.186,0.507] obj=[   0.25,   0.60,   0.73] sc=    0.559  <- OK
# (MERLION pid=33699) 15 w=[0.599,0.128,0.274] obj=[   0.25,   0.61,   0.72] sc=    0.425  <- OK
# (MERLION pid=33699) 16 w=[0.318,0.459,0.223] obj=[   0.23,   0.59,   0.69] sc=    0.496  <- OK
# (MERLION pid=33699) 17 w=[0.379,0.274,0.347] obj=[   0.35,   0.61,   0.70] sc=    0.540  <- OK
# (MERLION pid=33699) 18 w=[0.636,0.200,0.164] obj=[   0.31,   0.60,   0.69] sc=    0.431  <- OK
# (MERLION pid=33699) 19 w=[0.469,0.156,0.374] obj=[   0.33,   0.60,   0.72] sc=    0.518  <- OK
# (MERLION pid=33699) 20 w=[0.560,0.160,0.280] obj=[   0.25,   0.62,   0.72] sc=    0.440  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=507100
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 11) ===
# (MERLION pid=33699) 00 w=[0.228,0.197,0.575] obj=[   0.17,   0.62,   0.69] sc=    0.559  <- OK
# (MERLION pid=33699) 01 w=[0.380,0.418,0.202] obj=[   0.25,   0.61,   0.70] sc=    0.496  <- OK
# (MERLION pid=33699) 02 w=[0.253,0.236,0.511] obj=[   0.16,   0.62,   0.75] sc=    0.570  <- OK
# (MERLION pid=33699) 03 w=[0.513,0.277,0.210] obj=[   0.19,   0.57,   0.73] sc=    0.411  <- OK
# (MERLION pid=33699) 04 w=[0.411,0.365,0.223] obj=[   0.23,   0.60,   0.72] sc=    0.475  <- OK
# (MERLION pid=33699) 05 w=[0.644,0.202,0.154] obj=[   0.30,   0.60,   0.72] sc=    0.425  <- OK
# (MERLION pid=33699) 06 w=[0.284,0.198,0.518] obj=[   0.18,   0.61,   0.69] sc=    0.530  <- OK
# (MERLION pid=33699) 07 w=[0.483,0.163,0.354] obj=[   0.29,   0.59,   0.71] sc=    0.490  <- OK
# (MERLION pid=33699) 08 w=[0.464,0.184,0.352] obj=[   0.27,   0.61,   0.72] sc=    0.491  <- OK
# (MERLION pid=33699) 09 w=[0.537,0.201,0.262] obj=[   0.28,   0.60,   0.72] sc=    0.461  <- OK
# (MERLION pid=33699) 10 w=[0.573,0.174,0.254] obj=[   0.15,   0.62,   0.73] sc=    0.378  <- OK
# (MERLION pid=33699) 11 w=[0.459,0.192,0.349] obj=[   0.25,   0.59,   0.71] sc=    0.479  <- OK
# (MERLION pid=33699) 12 w=[0.554,0.304,0.142] obj=[   0.25,   0.59,   0.72] sc=    0.421  <- OK
# (MERLION pid=33699) 13 w=[0.364,0.199,0.437] obj=[   0.21,   0.59,   0.72] sc=    0.511  <- OK
# (MERLION pid=33699) 14 w=[0.732,0.166,0.102] obj=[   0.07,   0.62,   0.70] sc=    0.227  <- OK
# (MERLION pid=33699) 15 w=[0.434,0.191,0.375] obj=[   0.28,   0.61,   0.70] sc=    0.498  <- OK
# (MERLION pid=33699) 16 w=[0.474,0.256,0.270] obj=[   0.24,   0.60,   0.69] sc=    0.455  <- OK
# (MERLION pid=33699) 17 w=[0.576,0.420,0.004] obj=[   0.31,   0.59,   0.71] sc=    0.428  <- OK
# (MERLION pid=33699) 18 w=[0.451,0.285,0.263] obj=[   0.39,   0.60,   0.74] sc=    0.542  <- OK
# (MERLION pid=33699) 19 w=[0.457,0.169,0.375] obj=[   0.30,   0.62,   0.73] sc=    0.516  <- OK
# (MERLION pid=33699) 20 w=[0.579,0.248,0.173] obj=[   0.20,   0.59,   0.71] sc=    0.385  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=553200
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 12) ===
# (MERLION pid=33699) 00 w=[0.576,0.420,0.004] obj=[   0.39,   0.62,   0.71] sc=    0.487  <- OK
# (MERLION pid=33699) 01 w=[0.489,0.236,0.275] obj=[   0.09,   0.60,   0.69] sc=    0.375  <- OK
# (MERLION pid=33699) 02 w=[0.329,0.232,0.438] obj=[   0.20,   0.61,   0.72] sc=    0.524  <- OK
# (MERLION pid=33699) 03 w=[0.485,0.202,0.313] obj=[   0.23,   0.61,   0.73] sc=    0.463  <- OK
# (MERLION pid=33699) 04 w=[0.461,0.346,0.193] obj=[   0.16,   0.61,   0.70] sc=    0.422  <- OK
# (MERLION pid=33699) 05 w=[0.386,0.187,0.427] obj=[   0.23,   0.59,   0.71] sc=    0.503  <- OK
# (MERLION pid=33699) 06 w=[0.520,0.239,0.241] obj=[   0.16,   0.60,   0.70] sc=    0.394  <- OK
# (MERLION pid=33699) 07 w=[0.496,0.200,0.304] obj=[   0.30,   0.62,   0.71] sc=    0.487  <- OK
# (MERLION pid=33699) 08 w=[0.417,0.254,0.330] obj=[   0.22,   0.59,   0.72] sc=    0.482  <- OK
# (MERLION pid=33699) 09 w=[0.293,0.223,0.484] obj=[   0.23,   0.58,   0.71] sc=    0.539  <- OK
# (MERLION pid=33699) 10 w=[0.611,0.173,0.216] obj=[   0.15,   0.58,   0.72] sc=    0.346  <- OK
# (MERLION pid=33699) 11 w=[0.550,0.241,0.209] obj=[   0.34,   0.59,   0.71] sc=    0.474  <- OK
# (MERLION pid=33699) 12 w=[0.242,0.285,0.473] obj=[   0.15,   0.63,   0.70] sc=    0.547  <- OK
# (MERLION pid=33699) 13 w=[0.492,0.181,0.327] obj=[   0.31,   0.63,   0.72] sc=    0.502  <- OK
# (MERLION pid=33699) 14 w=[0.269,0.223,0.508] obj=[   0.40,   0.59,   0.73] sc=    0.612  <- OK
# (MERLION pid=33699) 15 w=[0.454,0.153,0.394] obj=[   0.31,   0.59,   0.73] sc=    0.519  <- OK
# (MERLION pid=33699) 16 w=[0.440,0.333,0.227] obj=[   0.35,   0.60,   0.72] sc=    0.516  <- OK
# (MERLION pid=33699) 17 w=[0.337,0.249,0.414] obj=[   0.26,   0.58,   0.73] sc=    0.538  <- OK
# (MERLION pid=33699) 18 w=[0.662,0.245,0.093] obj=[   0.32,   0.60,   0.73] sc=    0.426  <- OK
# (MERLION pid=33699) 19 w=[0.311,0.220,0.469] obj=[   0.20,   0.62,   0.70] sc=    0.527  <- OK
# (MERLION pid=33699) 20 w=[0.534,0.189,0.278] obj=[   0.22,   0.60,   0.71] sc=    0.424  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=599300
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 13) ===
# (MERLION pid=33699) 00 w=[0.576,0.420,0.004] obj=[   0.24,   0.60,   0.73] sc=    0.394  <- OK
# (MERLION pid=33699) 01 w=[0.322,0.233,0.445] obj=[   0.21,   0.59,   0.69] sc=    0.510  <- OK
# (MERLION pid=33699) 02 w=[0.433,0.234,0.333] obj=[   0.38,   0.59,   0.72] sc=    0.544  <- OK
# (MERLION pid=33699) 03 w=[0.619,0.165,0.216] obj=[   0.36,   0.59,   0.73] sc=    0.478  <- OK
# (MERLION pid=33699) 04 w=[0.456,0.325,0.219] obj=[   0.26,   0.61,   0.71] sc=    0.472  <- OK
# (MERLION pid=33699) 05 w=[0.402,0.299,0.299] obj=[   0.19,   0.60,   0.71] sc=    0.466  <- OK
# (MERLION pid=33699) 06 w=[0.411,0.146,0.443] obj=[   0.27,   0.63,   0.69] sc=    0.510  <- OK
# (MERLION pid=33699) 07 w=[0.450,0.233,0.317] obj=[   0.12,   0.61,   0.71] sc=    0.421  <- OK
# (MERLION pid=33699) 08 w=[0.459,0.332,0.208] obj=[   0.21,   0.60,   0.71] sc=    0.442  <- OK
# (MERLION pid=33699) 09 w=[0.292,0.252,0.457] obj=[   0.25,   0.61,   0.71] sc=    0.553  <- OK
# (MERLION pid=33699) 10 w=[0.410,0.314,0.276] obj=[   0.23,   0.60,   0.72] sc=    0.483  <- OK
# (MERLION pid=33699) 11 w=[0.350,0.275,0.375] obj=[   0.24,   0.60,   0.70] sc=    0.511  <- OK
# (MERLION pid=33699) 12 w=[0.441,0.334,0.225] obj=[   0.13,   0.62,   0.70] sc=    0.421  <- OK
# (MERLION pid=33699) 13 w=[0.490,0.256,0.254] obj=[   0.36,   0.61,   0.74] sc=    0.517  <- OK
# (MERLION pid=33699) 14 w=[0.355,0.278,0.367] obj=[   0.25,   0.59,   0.72] sc=    0.518  <- OK
# (MERLION pid=33699) 15 w=[0.501,0.261,0.238] obj=[   0.28,   0.61,   0.72] sc=    0.472  <- OK
# (MERLION pid=33699) 16 w=[0.492,0.386,0.121] obj=[   0.39,   0.58,   0.71] sc=    0.503  <- OK
# (MERLION pid=33699) 17 w=[0.392,0.346,0.263] obj=[   0.37,   0.61,   0.72] sc=    0.543  <- OK
# (MERLION pid=33699) 18 w=[0.229,0.278,0.492] obj=[   0.44,   0.58,   0.72] sc=    0.617  <- OK
# (MERLION pid=33699) 19 w=[0.472,0.234,0.294] obj=[   0.22,   0.62,   0.72] sc=    0.459  <- OK
# (MERLION pid=33699) 20 w=[0.481,0.359,0.160] obj=[   0.38,   0.60,   0.71] sc=    0.509  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=645400
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 14) ===
# (MERLION pid=33699) 00 w=[0.576,0.420,0.004] obj=[   0.25,   0.61,   0.73] sc=    0.406  <- OK
# (MERLION pid=33699) 01 w=[0.518,0.377,0.105] obj=[   0.25,   0.61,   0.70] sc=    0.432  <- OK
# (MERLION pid=33699) 02 w=[0.497,0.424,0.079] obj=[   0.14,   0.61,   0.72] sc=    0.390  <- OK
# (MERLION pid=33699) 03 w=[0.367,0.162,0.472] obj=[   0.31,   0.62,   0.71] sc=    0.550  <- OK
# (MERLION pid=33699) 04 w=[0.535,0.422,0.043] obj=[   0.28,   0.61,   0.71] sc=    0.441  <- OK
# (MERLION pid=33699) 05 w=[0.406,0.350,0.244] obj=[   0.27,   0.62,   0.73] sc=    0.505  <- OK
# (MERLION pid=33699) 06 w=[0.327,0.260,0.413] obj=[   0.30,   0.59,   0.68] sc=    0.531  <- OK
# (MERLION pid=33699) 07 w=[0.396,0.303,0.301] obj=[   0.27,   0.61,   0.71] sc=    0.503  <- OK
# (MERLION pid=33699) 08 w=[0.281,0.299,0.419] obj=[   0.30,   0.58,   0.73] sc=    0.562  <- OK
# (MERLION pid=33699) 09 w=[0.518,0.194,0.288] obj=[   0.28,   0.60,   0.72] sc=    0.470  <- OK
# (MERLION pid=33699) 10 w=[0.295,0.330,0.375] obj=[   0.21,   0.59,   0.72] sc=    0.525  <- OK
# (MERLION pid=33699) 11 w=[0.660,0.095,0.245] obj=[   0.13,   0.59,   0.69] sc=    0.313  <- OK
# (MERLION pid=33699) 12 w=[0.395,0.287,0.318] obj=[   0.24,   0.61,   0.70] sc=    0.490  <- OK
# (MERLION pid=33699) 13 w=[0.470,0.262,0.268] obj=[   0.25,   0.61,   0.71] sc=    0.465  <- OK
# (MERLION pid=33699) 14 w=[0.432,0.328,0.239] obj=[   0.22,   0.60,   0.70] sc=    0.458  <- OK
# (MERLION pid=33699) 15 w=[0.451,0.370,0.180] obj=[   0.25,   0.61,   0.72] sc=    0.467  <- OK
# (MERLION pid=33699) 16 w=[0.525,0.387,0.088] obj=[   0.34,   0.60,   0.73] sc=    0.474  <- OK
# (MERLION pid=33699) 17 w=[0.582,0.406,0.011] obj=[   0.42,   0.59,   0.73] sc=    0.493  <- OK
# (MERLION pid=33699) 18 w=[0.423,0.266,0.311] obj=[   0.27,   0.58,   0.69] sc=    0.483  <- OK
# (MERLION pid=33699) 19 w=[0.273,0.292,0.435] obj=[   0.26,   0.62,   0.74] sc=    0.571  <- OK
# (MERLION pid=33699) 20 w=[0.450,0.332,0.218] obj=[   0.19,   0.61,   0.70] sc=    0.441  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=691500
# (MERLION pid=33699)
# (MERLION pid=33699) === POPULATION OBJECTIVE BREAKDOWN (Iter 15) ===
# (MERLION pid=33699) 00 w=[0.660,0.095,0.245] obj=[   0.25,   0.57,   0.73] sc=    0.399  <- OK
# (MERLION pid=33699) 01 w=[0.499,0.368,0.133] obj=[   0.17,   0.62,   0.73] sc=    0.408  <- OK
# (MERLION pid=33699) 02 w=[0.394,0.214,0.391] obj=[   0.24,   0.61,   0.74] sc=    0.514  <- OK
# (MERLION pid=33699) 03 w=[0.421,0.223,0.356] obj=[   0.29,   0.59,   0.73] sc=    0.512  <- OK
# (MERLION pid=33699) 04 w=[0.484,0.275,0.241] obj=[   0.24,   0.59,   0.72] sc=    0.452  <- OK
# (MERLION pid=33699) 05 w=[0.509,0.399,0.093] obj=[   0.26,   0.62,   0.70] sc=    0.446  <- OK
# (MERLION pid=33699) 06 w=[0.589,0.352,0.059] obj=[   0.25,   0.58,   0.72] sc=    0.395  <- OK
# (MERLION pid=33699) 07 w=[0.442,0.255,0.304] obj=[   0.38,   0.57,   0.74] sc=    0.539  <- OK
# (MERLION pid=33699) 08 w=[0.566,0.150,0.284] obj=[   0.29,   0.61,   0.72] sc=    0.464  <- OK
# (MERLION pid=33699) 09 w=[0.493,0.263,0.244] obj=[   0.21,   0.59,   0.70] sc=    0.431  <- OK
# (MERLION pid=33699) 10 w=[0.382,0.184,0.433] obj=[   0.06,   0.63,   0.71] sc=    0.447  <- OK
# (MERLION pid=33699) 11 w=[0.521,0.365,0.114] obj=[   0.32,   0.57,   0.71] sc=    0.459  <- OK
# (MERLION pid=33699) 12 w=[0.301,0.231,0.468] obj=[   0.27,   0.56,   0.71] sc=    0.542  <- OK
# (MERLION pid=33699) 13 w=[0.433,0.306,0.261] obj=[   0.23,   0.62,   0.72] sc=    0.477  <- OK
# (MERLION pid=33699) 14 w=[0.283,0.270,0.447] obj=[   0.15,   0.63,   0.69] sc=    0.520  <- OK
# (MERLION pid=33699) 15 w=[0.510,0.378,0.113] obj=[   0.18,   0.59,   0.70] sc=    0.394  <- OK
# (MERLION pid=33699) 16 w=[0.426,0.229,0.346] obj=[   0.28,   0.58,   0.73] sc=    0.504  <- OK
# (MERLION pid=33699) 17 w=[0.410,0.215,0.375] obj=[   0.37,   0.60,   0.72] sc=    0.550  <- OK
# (MERLION pid=33699) 18 w=[0.661,0.144,0.195] obj=[   0.14,   0.61,   0.71] sc=    0.319  <- OK
# (MERLION pid=33699) 19 w=[0.443,0.317,0.240] obj=[   0.38,   0.62,   0.72] sc=    0.538  <- OK
# (MERLION pid=33699) 20 w=[0.562,0.368,0.070] obj=[   0.35,   0.61,   0.74] sc=    0.476  <- OK
# (MERLION pid=33699) ================================================================
# (MERLION pid=33699) [MERLION] timesteps_this_iter=46100, timesteps_total=737600
# 2026-01-22 00:04:31,247	WARNING tune.py:146 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2026-01-22 00:04:31,254	ERROR tune.py:794 -- Trials did not complete: [MERLION_moderate_sc_b3133_00000]
# 2026-01-22 00:04:31,254	INFO tune.py:798 -- Total run time: 2674.36 seconds (2674.35 seconds for the tuning loop).
# 2026-01-22 00:04:31,255	WARNING tune.py:804 -- Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
#
# KeyboardInterrupt

# %% [markdown]
# #### TO TRY NEXT:
# * Narrowing the profit range for normalisation >> hopefully when the the agent sees the profit has bigger portion, it affects more to the final rewards, then the agent will consider to put more weights into profit!
#
# #### NOTE, My observation on MERLION behaviour:
# It tends to increase the reward on the reward vector value that contributes more in the final scalar reward, which is expected. Consequently, it is sensitive to normalisation range. If we set normalisation range too broad --> initial reard contribution in the beginning will be low --> Merlion thinks that this reward has less significant impact to final scalar reward --> allocate the weights to other reward vector values and decreases the weight for this one.

# %% [markdown]
# ### METAMORL
# timesteps = W (S + 1) H
#
# ### MERLION
# H = max(timestep/episode, rollout_fragment_length)
# S = inner_adaptation_steps
# W = num_rollout_workers
# P = population_size
# J = meta_batch_size
#
# timesteps = W (S + 1) H + P (J (S + 1) H + H)
#             {metaMORL-like} {population-stage}
#
# A timestep represents an agent-environment interaction sampling.
#
# In MERLION, the task batch size is defined in meta_batch_size, while num_rollout_workers only determine the parallel computation for speed. In Metamorl, the n_tasks is defined based on num_rollout_worker, so it is attached to the core number used.
#
# In MERLION, the iteration is calculated for the overall population, hence each individual solution learns much less iteration than Metamorl. The justification is because each individual solution learns locally, focusing within narrower search space.
#
# ### How the iteration works:
#
# each MERLION individual θᵢ gets fewer total updates than the single MetaMORL meta-policy,
#
# “each individual solution learns locally, focusing within a narrower search space”
#
# because the sample budget is spread across many individuals rather than concentrated on one.
#
# So:
#
# As a theoretical / structural statement: say
#
# “Per global iteration, MERLION trains all individuals; cost scales with P×meta_batch_size.”
#
# As a fair-sample comparison statement: say
#
# “For a fixed environment step budget, each MERLION individual effectively sees fewer updates than a single MetaMORL meta-policy, trading depth per policy for coverage/diversity across the population.”
#
# PS: Total running time in MERLION might more than MetaMORL since aside from metapolicy update (inner and outer), it also involves weight update thru evolutionary mechanism.
#
# NOTE: Currently, MERLION still contains MetaMORL-like update which is actually algorithmically unnecessary but needed. Hence, these stage can be ignored for iteration and timing.
#
# What happens if you “remove Phase 1”? If by “remove Phase 1” you mean: delete inner_adaptation_steps transform, stop producing (samples, metrics_dict), and leave MERLIONMetaUpdate.__call__ untouched,
#
# then:
#
# data_tuple will no longer be a 2-tuple, _shared_samples = data_tuple[0] will be wrong, you’ll get shape/TypeErrors → so yes, bugs.
#
# This is not because of Ray API, but because your execution_plan and MERLIONMetaUpdate are coupled.
#
# #### For now, let's just do interpolation to ignore MetaMORL update and upgrade version later maybe.

# %% [markdown]
# ### Try to fine-tune using stable-baselines3

# %%
from stable_baselines3 import PPO
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from _merlion.fine_tuning.ft_moderate_env_merlion import TestModerateSC
from _metamorl.algo_ray.rllib.algorithms.maml import merlion_finetuning_sb3_independent as ft

# %%
# (Re)start Ray cleanly
ray.shutdown()
ray.init(ignore_reinit_error=True, include_dashboard=False)

def make_env_ray(config):
    """
    RLlib factory: receives a dict `config` and must return a *Gymnasium Env instance*.
    We wrap with TimeLimit here so both RLlib and Gym share the same horizon behavior.
    """
    base = TestModerateSC(**config)            # pass config keys into your env
    max_steps = int(config.get("max_steps", 100))
    return TimeLimit(base, max_episode_steps=max_steps)

register_env("testSC", make_env_ray)
register_env("moderate_sc", lambda cfg: moderate_env_merlion.make_env(cfg)) # register meta-env
# Out:
# 2026-01-28 10:20:21,530	WARNING utils.py:640 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2026-01-28 10:20:21,531	WARNING utils.py:652 -- Ray currently does not support initializing Raywith fractional cpus. Your num_cpus will be truncated from 13.68 to 13.
# 2026-01-28 10:20:21,533	WARNING services.py:1780 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=10.24gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2026-01-28 10:20:21,570	INFO worker.py:1553 -- Started a local Ray instance.

# %%
# Optional: re-register safely if re-running cells
try:
    gym.spec("testSC")  # raises if not registered
    # Gymnasium 0.29.x: remove existing spec to allow re-register
    del gym.envs.registration.registry["testSC"]
except Exception:
    pass

def make_env_gym(**kwargs):
    base = TestModerateSC(**kwargs)
    max_steps = int(kwargs.get("max_steps", 100))
    return TimeLimit(base, max_episode_steps=max_steps)

gym.register(
    id="testSC",
    entry_point=make_env_gym,   # callable that returns an Env
)

# %% [markdown]
# Finetuning timesteps = P x (M + 1) x K x W
#
# P: population size
#
# M: number of local perturbation
#
# K: env steps per perturbation
#
# W: rollout workers

# %%
#finetuning timesteps = 10 x 5 x 100 x 1 = 5000 timesteps
runs = 10
for k in range(8, runs):
    start_time = time.time()
    ft.finetune_with_local_perturbations(
        pop_dir=f"/home/rifnyrachman7/_merlion/training_data/moderate_sc/metapolicies-{k}",
        env_id="testSC",
        out_dir=f"/home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-{k}",
        total_steps=16000, # default 5000
        record_every=512, # default 1
        eval_episodes=50, # default 50
        m_perturb=2,
        eps=0.05,
        seed=7,
        skip_existing=True,
    )
    end_time = time.time()
    print(f"fine-tuning run-{k}:",end_time - start_time,"seconds")
# Out:
# 2026-01-06 10:00:19,447	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2026-01-06 10:00:19,447	WARNING algorithm_config.py:596 -- Cannot create MERLIONConfig from given `config_dict`! Property __stdout_file__ not supported.
# 2026-01-06 10:00:19,487	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2026-01-06 10:00:19,487	INFO algorithm.py:506 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# === Meta-policy 0 ===
# (RolloutWorker pid=2878) 2026-01-06 10:00:22,767	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=2878) 2026-01-06 10:00:22,767	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=2878) 2026-01-06 10:00:22,767	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=2878) 2026-01-06 10:00:22,767	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:00:23,845	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2026-01-06 10:00:23,845	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# 2026-01-06 10:00:23,846	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:00:23,846	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:00:26,619	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# 2026-01-06 10:00:26,619	WARNING deprecation.py:50 -- DeprecationWarning: `remote_workers()` has been deprecated. Accessing the list of remote workers directly through remote_workers() is strongly discouraged. Please try to use one of the foreach accessors that is fault tolerant.  This will raise an error in the future!
# (RolloutWorker pid=3208) 2026-01-06 10:00:29,553	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3208) 2026-01-06 10:00:29,553	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3208) 2026-01-06 10:00:29,553	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3208) 2026-01-06 10:00:29,553	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:00:30,206	INFO trainable.py:172 -- Trainable.setup took 10.720 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:00:30,207	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i000_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i000_m-1 already exists, loading existing results into summaries.
# [skip+load] i000_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i000_m00 already exists, loading existing results into summaries.
# [skip+load] i000_m01: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i000_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 1 ===
# (RolloutWorker pid=3291) 2026-01-06 10:00:34,045	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3291) 2026-01-06 10:00:34,045	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3291) 2026-01-06 10:00:34,046	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3291) 2026-01-06 10:00:34,046	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3561) 2026-01-06 10:00:40,335	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3561) 2026-01-06 10:00:40,335	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3561) 2026-01-06 10:00:40,336	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3561) 2026-01-06 10:00:40,336	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:00:41,032	INFO trainable.py:172 -- Trainable.setup took 10.098 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:00:41,033	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i001_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i001_m-1 already exists, loading existing results into summaries.
# [skip+load] i001_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i001_m00 already exists, loading existing results into summaries.
# [skip+load] i001_m01: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i001_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 2 ===
# (RolloutWorker pid=3632) 2026-01-06 10:00:45,037	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3632) 2026-01-06 10:00:45,037	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3632) 2026-01-06 10:00:45,037	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3632) 2026-01-06 10:00:45,037	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3903) 2026-01-06 10:00:51,276	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3903) 2026-01-06 10:00:51,276	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3903) 2026-01-06 10:00:51,276	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3903) 2026-01-06 10:00:51,276	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:00:51,955	INFO trainable.py:172 -- Trainable.setup took 10.197 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:00:51,956	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i002_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i002_m-1 already exists, loading existing results into summaries.
# [skip+load] i002_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i002_m00 already exists, loading existing results into summaries.
# [skip+load] i002_m01: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i002_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 3 ===
# (RolloutWorker pid=3974) 2026-01-06 10:00:55,866	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3974) 2026-01-06 10:00:55,866	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=3974) 2026-01-06 10:00:55,866	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=3974) 2026-01-06 10:00:55,866	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4244) 2026-01-06 10:01:01,969	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4244) 2026-01-06 10:01:01,969	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4244) 2026-01-06 10:01:01,969	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4244) 2026-01-06 10:01:01,969	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:01:02,686	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i003_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i003_m-1 already exists, loading existing results into summaries.
# [skip+load] i003_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i003_m00 already exists, loading existing results into summaries.
# [skip+load] i003_m01: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i003_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 4 ===
# (RolloutWorker pid=4315) 2026-01-06 10:01:06,732	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4315) 2026-01-06 10:01:06,732	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4315) 2026-01-06 10:01:06,733	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4315) 2026-01-06 10:01:06,733	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4585) 2026-01-06 10:01:12,859	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4585) 2026-01-06 10:01:12,859	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4585) 2026-01-06 10:01:12,859	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4585) 2026-01-06 10:01:12,859	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:01:13,545	INFO trainable.py:172 -- Trainable.setup took 10.133 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:01:13,546	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i004_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i004_m-1 already exists, loading existing results into summaries.
# [skip+load] i004_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i004_m00 already exists, loading existing results into summaries.
# [skip+load] i004_m01: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i004_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 5 ===
# (RolloutWorker pid=4656) 2026-01-06 10:01:17,462	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4656) 2026-01-06 10:01:17,462	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4656) 2026-01-06 10:01:17,463	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4656) 2026-01-06 10:01:17,463	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4926) 2026-01-06 10:01:23,826	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4926) 2026-01-06 10:01:23,826	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4926) 2026-01-06 10:01:23,826	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4926) 2026-01-06 10:01:23,826	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:01:24,523	INFO trainable.py:172 -- Trainable.setup took 10.246 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:01:24,525	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i005_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i005_m-1 already exists, loading existing results into summaries.
# [skip+load] i005_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i005_m00 already exists, loading existing results into summaries.
# [skip+load] i005_m01: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i005_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 6 ===
# (RolloutWorker pid=4997) 2026-01-06 10:01:28,364	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4997) 2026-01-06 10:01:28,364	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=4997) 2026-01-06 10:01:28,364	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=4997) 2026-01-06 10:01:28,364	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5267) 2026-01-06 10:01:34,622	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5267) 2026-01-06 10:01:34,622	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5267) 2026-01-06 10:01:34,623	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5267) 2026-01-06 10:01:34,623	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:01:35,301	INFO trainable.py:172 -- Trainable.setup took 10.051 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:01:35,302	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i006_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i006_m-1 already exists, loading existing results into summaries.
# [skip+load] i006_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i006_m00 already exists, loading existing results into summaries.
# [skip+load] i006_m01: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i006_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 7 ===
# (RolloutWorker pid=5338) 2026-01-06 10:01:39,289	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5338) 2026-01-06 10:01:39,289	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5338) 2026-01-06 10:01:39,289	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5338) 2026-01-06 10:01:39,289	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5608) 2026-01-06 10:01:45,639	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5608) 2026-01-06 10:01:45,639	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5608) 2026-01-06 10:01:45,639	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5608) 2026-01-06 10:01:45,639	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:01:46,332	INFO trainable.py:172 -- Trainable.setup took 10.224 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:01:46,333	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i007_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i007_m-1 already exists, loading existing results into summaries.
# [skip+load] i007_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i007_m00 already exists, loading existing results into summaries.
# [skip+load] i007_m01: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i007_m01 already exists, loading existing results into summaries.
#
# === Meta-policy 8 ===
# (RolloutWorker pid=5679) 2026-01-06 10:01:50,281	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5679) 2026-01-06 10:01:50,281	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5679) 2026-01-06 10:01:50,282	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5679) 2026-01-06 10:01:50,282	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5950) 2026-01-06 10:01:56,568	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5950) 2026-01-06 10:01:56,568	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=5950) 2026-01-06 10:01:56,568	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=5950) 2026-01-06 10:01:56,568	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:01:57,263	INFO trainable.py:172 -- Trainable.setup took 10.202 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:01:57,264	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [skip+load] i008_m-1: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i008_m-1 already exists, loading existing results into summaries.
# [skip+load] i008_m00: /home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-8/i008_m00 already exists, loading existing results into summaries.
#   [warn] weight.json missing, using w_im from schedule.
#   [warn] learning_curve.csv not found; offspring not added to summary.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# === Meta-policy 9 ===
# (RolloutWorker pid=6151) 2026-01-06 10:09:45,118	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6151) 2026-01-06 10:09:45,118	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6151) 2026-01-06 10:09:45,118	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6151) 2026-01-06 10:09:45,118	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6421) 2026-01-06 10:09:51,328	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6421) 2026-01-06 10:09:51,328	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6421) 2026-01-06 10:09:51,329	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6421) 2026-01-06 10:09:51,329	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:09:52,015	INFO trainable.py:172 -- Trainable.setup took 10.040 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:09:52,016	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 10 ===
# (RolloutWorker pid=6863) 2026-01-06 10:32:48,867	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6863) 2026-01-06 10:32:48,867	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=6863) 2026-01-06 10:32:48,867	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=6863) 2026-01-06 10:32:48,867	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7133) 2026-01-06 10:32:54,911	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7133) 2026-01-06 10:32:54,911	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7133) 2026-01-06 10:32:54,911	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7133) 2026-01-06 10:32:54,911	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:32:55,609	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 11 ===
# (RolloutWorker pid=7539) 2026-01-06 10:55:55,022	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7539) 2026-01-06 10:55:55,022	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7539) 2026-01-06 10:55:55,023	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7539) 2026-01-06 10:55:55,023	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7810) 2026-01-06 10:56:01,217	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7810) 2026-01-06 10:56:01,217	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=7810) 2026-01-06 10:56:01,217	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=7810) 2026-01-06 10:56:01,217	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 10:56:01,907	INFO trainable.py:172 -- Trainable.setup took 10.147 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 10:56:01,909	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 12 ===
# (RolloutWorker pid=8213) 2026-01-06 11:18:53,254	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8213) 2026-01-06 11:18:53,254	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8213) 2026-01-06 11:18:53,255	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8213) 2026-01-06 11:18:53,255	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8483) 2026-01-06 11:18:59,412	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8483) 2026-01-06 11:18:59,412	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8483) 2026-01-06 11:18:59,412	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8483) 2026-01-06 11:18:59,412	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 11:19:00,109	INFO trainable.py:172 -- Trainable.setup took 10.073 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 11:19:00,111	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 13 ===
# (RolloutWorker pid=8895) 2026-01-06 11:42:06,784	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8895) 2026-01-06 11:42:06,784	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=8895) 2026-01-06 11:42:06,784	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=8895) 2026-01-06 11:42:06,784	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=9165) 2026-01-06 11:42:12,792	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9165) 2026-01-06 11:42:12,792	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9165) 2026-01-06 11:42:12,792	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=9165) 2026-01-06 11:42:12,792	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 11:42:13,471	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 14 ===
# (RolloutWorker pid=9574) 2026-01-06 12:05:13,140	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9574) 2026-01-06 12:05:13,140	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9574) 2026-01-06 12:05:13,140	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=9574) 2026-01-06 12:05:13,140	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=9844) 2026-01-06 12:05:19,180	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9844) 2026-01-06 12:05:19,180	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=9844) 2026-01-06 12:05:19,180	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=9844) 2026-01-06 12:05:19,180	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 12:05:19,855	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 15 ===
# (RolloutWorker pid=10251) 2026-01-06 12:28:25,734	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10251) 2026-01-06 12:28:25,734	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10251) 2026-01-06 12:28:25,734	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=10251) 2026-01-06 12:28:25,734	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=10521) 2026-01-06 12:28:31,446	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10521) 2026-01-06 12:28:31,446	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10521) 2026-01-06 12:28:31,446	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=10521) 2026-01-06 12:28:31,446	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 12:28:32,087	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 16 ===
# (RolloutWorker pid=10932) 2026-01-06 12:51:53,863	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10932) 2026-01-06 12:51:53,863	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=10932) 2026-01-06 12:51:53,863	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=10932) 2026-01-06 12:51:53,863	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# ...
# (RolloutWorker pid=22505) 2026-01-06 19:39:43,849	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=22505) 2026-01-06 19:39:43,849	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=22775) 2026-01-06 19:39:50,109	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=22775) 2026-01-06 19:39:50,109	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=22775) 2026-01-06 19:39:50,109	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=22775) 2026-01-06 19:39:50,109	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 19:39:50,825	INFO trainable.py:172 -- Trainable.setup took 10.208 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-06 19:39:50,826	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 13 ===
# (RolloutWorker pid=23207) 2026-01-06 20:05:12,902	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23207) 2026-01-06 20:05:12,902	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23207) 2026-01-06 20:05:12,903	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=23207) 2026-01-06 20:05:12,903	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=23478) 2026-01-06 20:05:18,941	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23478) 2026-01-06 20:05:18,941	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23478) 2026-01-06 20:05:18,941	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=23478) 2026-01-06 20:05:18,941	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 20:05:19,624	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 14 ===
# (RolloutWorker pid=23884) 2026-01-06 20:29:43,773	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23884) 2026-01-06 20:29:43,773	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=23884) 2026-01-06 20:29:43,773	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=23884) 2026-01-06 20:29:43,773	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=24154) 2026-01-06 20:29:49,863	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=24154) 2026-01-06 20:29:49,863	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=24154) 2026-01-06 20:29:49,864	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=24154) 2026-01-06 20:29:49,864	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 20:29:50,557	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 15 ===
# (RolloutWorker pid=24561) 2026-01-06 20:55:05,256	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=24561) 2026-01-06 20:55:05,256	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=24561) 2026-01-06 20:55:05,256	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=24561) 2026-01-06 20:55:05,256	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=24831) 2026-01-06 20:55:11,316	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=24831) 2026-01-06 20:55:11,316	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=24831) 2026-01-06 20:55:11,316	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=24831) 2026-01-06 20:55:11,316	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 20:55:11,987	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 16 ===
# (RolloutWorker pid=25238) 2026-01-06 21:19:38,172	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=25238) 2026-01-06 21:19:38,172	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=25238) 2026-01-06 21:19:38,172	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=25238) 2026-01-06 21:19:38,172	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=25509) 2026-01-06 21:19:43,994	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=25509) 2026-01-06 21:19:43,994	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=25509) 2026-01-06 21:19:43,995	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=25509) 2026-01-06 21:19:43,995	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 21:19:44,662	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
#
# === Meta-policy 17 ===
# (RolloutWorker pid=25919) 2026-01-06 21:45:16,546	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=25919) 2026-01-06 21:45:16,546	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=25919) 2026-01-06 21:45:16,546	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=25919) 2026-01-06 21:45:16,546	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=26189) 2026-01-06 21:45:22,548	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=26189) 2026-01-06 21:45:22,548	WARNING env.py:156 -- Your env doesn't have a .spec.max_episode_steps attribute. Your horizon will default to infinity, and your environment will not be reset.
# (RolloutWorker pid=26189) 2026-01-06 21:45:22,548	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# (RolloutWorker pid=26189) 2026-01-06 21:45:22,548	WARNING env.py:166 -- Your env reset() method appears to take 'seed' or 'return_info' arguments. Note that these are not yet supported in RLlib. Seeding will take place using 'env.seed()' and the info dict will not be returned from reset.
# 2026-01-06 21:45:23,216	WARNING util.py:67 -- Install gputil for GPU system monitoring.
# [warn] No overlapping keys between RLlib policy and SB3 policy; using SB3 init.
# /home/rifnyrachman7/_metamorl/algo_ray/rllib/algorithms/maml/evaluate_merlion.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# ### Load the model to print policy

# %%
ENV_ID     = "testSC"
run = 9
MODEL_PATH = f"/home/rifnyrachman7/_merlion/training_data/moderate_sc/finetuning_sb3-{run}/i003_m01/sb3_model.zip"  # <- your file

env = gym.make(ENV_ID, max_steps=100)
model = PPO.load(MODEL_PATH, env=env)

# Try to obtain human-readable action labels, otherwise use a[i]
action_labels = None
ue = getattr(env, "unwrapped", env)
for attr in ("get_action_names", "action_names", "action_labels"):
    if hasattr(ue, attr):
        names = getattr(ue, attr)
        action_labels = names() if callable(names) else names
        break

CSV_OUT    = f"/home/rifnyrachman7/_merlion/visualisation/action_mod_merlion-{run}.csv"
obs, info = env.reset()
rows = []
t = 0
while True:
    action, _ = model.predict(obs, deterministic=False)
    action = np.array(action).ravel()

    row = {"t": t}
    if action_labels and len(action_labels) == action.size:
        for name, val in zip(action_labels, action):
            row[name] = float(val)
    else:
        for i, val in enumerate(action):
            row[f"a{i}"] = float(val)

    # Optional: capture reward vector if the env provides it
    mo = info.get("mo_reward")
    if mo is not None and len(mo) >= 3:
        row["profit"]    = float(mo[0])
        row["emission"]  = float(mo[1])
        row["inequality"]= float(mo[2])

    rows.append(row)

    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        break
    t += 1

env.close()

df = pd.DataFrame(rows)
df.to_csv(CSV_OUT, index=False)
print(f"Saved action plan to {CSV_OUT}")
# Out:
# Saved action plan to /home/rifnyrachman7/_merlion/visualisation/action_mod_merlion-9.csv
